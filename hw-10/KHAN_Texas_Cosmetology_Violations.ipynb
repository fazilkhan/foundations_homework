# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
driver = webdriver.Chrome()

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for **cosmetologist violations** for people with the last name **Nguyen**.

# %%
driver.get("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")

# %%
driver.find_element_by_id("pht_status").send_keys("Cosmetologists")
driver.find_element_by_id("pht_lnm").send_keys("Nguyen")
button = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]")
button.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
table_rows = driver.find_elements_by_tag_name("tr")
for row in table_rows[:10]:
    print(row.text.strip())
    print("----------")
# Out:
# Name and Location Order Basis for Order
# ----------
# NGUYEN, HUNG VU
# City: HOUSTON
# County: HARRIS
# Zip Code: 77086
#
#
# License #: 730692
#
# Complaint # COS20190011025 Date: 11/24/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,375. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to discard single use implements after each use; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# ----------
# NGUYEN, MIMI PHAM
# City: KATY
# County: HARRIS
# Zip Code: 77449
#
#
# License #: 784210
#
# Complaint # COS20190010072 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# ----------
# NGUYEN, HA
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76017
#
#
# License #: 764888
#
# Complaint # COS20190016762 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $2,250. Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# ----------
# NGUYEN, THAO HONG
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78238
#
#
# License #(s): 799926, 1753491
#
# Complaint # COS20200010387 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ----------
# NGUYEN, MAI
# City: MESQUITE
# County: DALLAS
# Zip Code: 75150
#
#
# License #: 687294
#
# Complaint # COS20200007264 Date: 10/29/2020
#
# Respondent is assessed an administrative penalty in the amount of $2,750. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# ----------
# NGUYEN, CINDY
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78414
#
#
# License #(s): 806232, 1260359, 1280071
#
# Complaint # COS20200010502 Date: 10/29/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# ----------
# NGUYEN, CHAU KHANH LINH
# City: MONTGOMERY
# County: OUT OF STATE
# Zip Code: 36116
#
#
# License #: 1764073
#
# Complaint # COS20190008104 Date: 10/26/2020
#
# The Respondent's Cosmetology Manicurist license is revoked. Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# ----------
# NGUYEN, TRANG T
# City: SEGUIN
# County: GUADALUPE
# Zip Code: 78155
#
#
# License #: 748483
#
# Complaint # COS20200010511 Date: 10/26/2020
#
# Respondent is assessed an administrative penalty in the amount of $935. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# ----------
# NGUYEN, DUNG MINH
# City: HOUSTON
# County: HARRIS
# Zip Code: 77066
#
#
# License #: 785878
#
# Complaint # COS20200004202 Date: 10/19/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# ----------

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    # Instead of stopping on an error, it'll jump down here instead
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement. Most people use `pass`, but it's also nice to print out debug statements so you know when/where it's running into errors.
#
# **Why doesn't the first one have a name?**

# %%
table_cells = driver.find_elements_by_tag_name("td")
table_cells[5].text.strip()
# Out:
# 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.'

# %%
for row in table_rows:
    try:
        print(row.find_element_by_class_name("results_text").text.strip())
    except:
        print("Did not work")
#     for cell in table_cells[:10]:
# Out:
# Did not work
# NGUYEN, HUNG VU
# NGUYEN, MIMI PHAM
# NGUYEN, HA
# NGUYEN, THAO HONG
# NGUYEN, MAI
# NGUYEN, CINDY
# NGUYEN, CHAU KHANH LINH
# NGUYEN, TRANG T
# NGUYEN, DUNG MINH
# NGUYEN, YEN NHI THI
# NGUYEN, JOHNNY DAT
# NGUYEN, KELLY PHUONG N
# NGUYEN, NGA THU
# NGUYEN, IVY
# NGUYEN, DIEMTRINH T
# NGUYEN, HUAN CAO
# NGUYEN, THOA KIM
# NGUYEN, TONY
# NGUYEN, HIEN
# NGUYEN, NGOC TRAM
# NGUYEN, TRAN NAM
# NGUYEN, PHILLIP
# NGUYEN, THUY T
# NGUYEN, TRACY
# NGUYEN, LE PHUC
# NGUYEN, HAI MINH
# NGUYEN, TUYET
# NGUYEN, BA VAN
# NGUYEN, LAN THANH
# NGUYEN, PHUOC BA
# NGUYEN, LINH THUY KIEU
# NGUYEN, TONY MINH
# NGUYEN, THANH
# NGUYEN, HIEN THI MINH
# NGUYEN, VAN NGOC THAO
# NGUYEN, TAM THANH
# NGUYEN, ANDY HUU
# NGUYEN, CUONG HULL
# NGUYEN, NANCY HOA
# NGUYEN, THOA THI KIM
# NGUYEN, TRANG
# NGUYEN, THONG VAN
# NGUYEN, TUAN
# NGUYEN, LYNDA
# NGUYEN, CATHY H
# NGUYEN, PAMELA DAN
# NGUYEN, SON QUOC
# NGUYEN, KIM
# NGUYEN, THAI VAN
# NGUYEN, HANH THI
# NGUYEN, DIEP THI NGOC
# NGUYEN, CASEY
# NGUYEN, ANTHONY VAN
# NGUYEN, CHRISTINA D
# NGUYEN, PHUONG T
# NGUYEN, KENNY
# NGUYEN, THAO (MINH THAO
# NGUYEN, KENNY
# NGUYEN, BA VAN
# NGUYEN, KHUYEN THI
# NGUYEN, SON DANG
# NGUYEN, TUYEN THANH
# NGUYEN, STEVEN THAI
# NGUYEN, CY VAN
# NGUYEN, QUANG DUC
# NGUYEN, OANH THI
# NGUYEN, AN QUY
# NGUYEN, HAU PHUC
# NGUYEN, KIM LIEN THI
# NGUYEN, KENNY KHANH
# NGUYEN, KIM LAN THI
# NGUYEN, DUONG VAN
# NGUYEN, HIEU CHAU
# NGUYEN, TRANG KIM
# NGUYEN, LINH H
# NGUYEN, PHUONG DUC
# NGUYEN, NGUYET M
# NGUYEN, VAN DO THI
# NGUYEN, XUAN THI
# NGUYEN, MICHAEL TAN
# NGUYEN, LANCHI
# NGUYEN, DIEM
# NGUYEN, LINH K
# NGUYEN, THOANG THI
# NGUYEN, HOAI THU T
# NGUYEN, JIMMY DUC
# NGUYEN, NINH VAN
# NGUYEN, THANH HUU
# NGUYEN, UYEN THI TU
# NGUYEN, BANH THI
# NGUYEN, KHIET THANH
# NGUYEN, SAM DUC
# NGUYEN, ANH HUU
# NGUYEN, DIANE N
# NGUYEN, MICHAEL
# NGUYEN, CUONG TRAN
# NGUYEN, TRAN NAM
# NGUYEN, TAMMY
# NGUYEN, SUONG THI TRUC
# NGUYEN, THE THI
# NGUYEN, KIMBERLY
# NGUYEN, DUY KINH
# NGUYEN, LEENA L
# NGUYEN, MAI TRANG
# NGUYEN, HUYEN T
# NGUYEN, TUNG T
# NGUYEN, HIEN XUAN T
# NGUYEN, TUYET
# NGUYEN, HUYEN THI-MINH
# NGUYEN, HOA VAN
# NGUYEN, PAUL
# NGUYEN, LOAN HONG ANH
# NGUYEN, MAI THI BACH
# NGUYEN, TUYET-MAI PHAM
# NGUYEN, LIEN THI B
# NGUYEN, MAI T
# NGUYEN, LIEN
# NGUYEN, NGOC THI
# NGUYEN, VIET LINH
# NGUYEN, COURTNEY
# NGUYEN, TUYEN T
# NGUYEN, NHON A
# NGUYEN, SOPHIE T
# NGUYEN, NGOC HONG THI
# NGUYEN, KHAN THI
# NGUYEN, ANNA AI
# NGUYEN, NHU MAI
# NGUYEN, DUNG QUANG
# NGUYEN, MINH THU
# NGUYEN, PHUONG THI
# NGUYEN, CHARLIE
# NGUYEN, HANH THI
# NGUYEN, MINH V
# NGUYEN, NHAN THANH
# NGUYEN, THUYET
# NGUYEN, QUANG XUAN
# NGUYEN, TRUNG N
# NGUYEN, MYCAM THI
# NGUYEN, THUYVI T
# NGUYEN, OANH PHUONG
# NGUYEN, QUANG Q
# NGUYEN, CINDY
# NGUYEN, KEVIN HOA
# NGUYEN, THUY T
# NGUYEN, THIENTRANG THI
# NGUYEN, MARY ANN
# NGUYEN, THANH CHUONG
# NGUYEN, PHUONG N
# NGUYEN, ANH TRAM
# NGUYEN, HIEN
# NGUYEN, TUAN A
# NGUYEN, LEON A
# NGUYEN, VINH QUANG
# NGUYEN, BINH VAN
# NGUYEN, SHARON
# NGUYEN, BINH THANH
# NGUYEN, SAMANTHA TRAN
# NGUYEN, THU LE
# NGUYEN, KIM NGAN THI

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...*

# %%
for row in table_rows:
    try:
        print(row.find_elements_by_tag_name("td")[2].text.strip())
    except:
        print("Did not work")
    print("--------")
# Out:
# Did not work
# --------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to discard single use implements after each use; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# --------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# --------
# Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# --------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# --------
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# --------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# --------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.
# --------
# Respondent failed properly clean and sanitize the metal implements used at the Salon.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent failed to clean and disinfect all wax pots.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to cooperate with the inspector in the performance of an inspection.
# --------
# Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# --------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.
# --------
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# --------
# Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# --------
# Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# --------
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent operated a cosmetology salon without the appropriate license.
# --------
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent stored chemicals in a restroom accessible to the public.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# --------
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used constitutes two violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# --------
# Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# --------
# On two (2) occasions, Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent performed or attempted to perform a practice of cosmetology with an expired license. Respondent operated a cosmetology salon without the appropriate license.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# --------
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent employed a person as an operator who did not hold a license.
# --------
# Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# --------
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent performed barbering without the required license.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots.
# --------
# Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to cooperate with the inspector in the performance of an inspection.
# --------
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent operated a cosmetology salon without the appropriate license; Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to dispose of single use items after each use.
# --------
# Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.
# --------
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent failed to properly disinfect implements at the end of each day.
# --------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.
# --------
# Respondent failed to clean and disinfect all wax pots.
# --------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# --------
# Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day; Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent failed to clean and disinfect all wax pots.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# --------
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# --------
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to properly disinfect implements at the end of each day.
# --------
# Respondent failed to dispose of single use items after each use.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to ensure that only semi-permanent glue was used during eyelash extension services.
# --------
# Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.
# --------
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# --------
# Respondent failed to dispose of single use items after each use.
# --------
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# --------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# --------
# Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of a crime that was committed within 5 years of their renewal application; Respondent lacks sufficient honesty, trustworthiness and integrity to hold a license.
# --------
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# --------
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# --------
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# --------
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# --------
# Respondent failed to comply with an order previously issued by the Executive Director.
# --------
# Respondent interfered with a Department inspection of the salon.
# --------

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for row in table_rows:
    print("Complaint #:")
    try:
        print(row.find_elements_by_tag_name("span")[10].text.strip())
    except:
        print("Did not work")
    print("--------")
# Out:
# Complaint #:
# Did not work
# --------
# Complaint #:
# COS20190011025
# --------
# Complaint #:
# COS20190010072
# --------
# Complaint #:
# COS20190016762
# --------
# Complaint #:
# COS20200010387
# --------
# Complaint #:
# COS20200007264
# --------
# Complaint #:
# COS20200010502
# --------
# Complaint #:
# COS20190008104
# --------
# Complaint #:
# COS20200010511
# --------
# Complaint #:
# COS20200004202
# --------
# Complaint #:
# COS20190004199
# --------
# Complaint #:
# COS20200000101
# --------
# Complaint #:
# COS20200011664
# --------
# Complaint #:
# COS20200010961
# --------
# Complaint #:
# COS20200008858
# --------
# Complaint #:
# COS20200008859
# --------
# Complaint #:
# COS20200009732
# --------
# Complaint #:
# COS20200006548
# --------
# Complaint #:
# COS20200009605
# --------
# Complaint #:
# COS20190016479
# --------
# Complaint #:
# COS20190012148
# --------
# Complaint #:
# COS20190010318
# --------
# Complaint #:
# COS20190014688
# --------
# Complaint #:
# COS20190004016
# --------
# Complaint #:
# COS20190016499
# --------
# Complaint #:
# COS20200006146
# --------
# Complaint #:
# COS20190016549
# --------
# Complaint #:
# COS20190017217
# --------
# Complaint #:
# COS20190016854
# --------
# Complaint #:
# COS20190017175
# --------
# Complaint #:
# COS20190013017
# --------
# Complaint #:
# COS20190016161
# --------
# Complaint #:
# COS20200000652
# --------
# Complaint #:
# COS20190007906
# --------
# Complaint #:
# COS20190003737
# --------
# Complaint #:
# COS20190006118
# --------
# Complaint #:
# COS20200002642
# --------
# Complaint #:
# COS20190009211
# --------
# Complaint #:
# COS20190010611
# --------
# Complaint #:
# COS20190010665
# --------
# Complaint #:
# COS20190001932
# --------
# Complaint #:
# COS20190014576
# --------
# Complaint #:
# COS20190001897
# --------
# Complaint #:
# COS20190009239
# --------
# Complaint #:
# COS20190009484
# --------
# Complaint #:
# County:
# --------
# Complaint #:
# COS20190011923
# --------
# Complaint #:
# COS20190005539
# --------
# Complaint #:
# COS20190010176
# --------
# Complaint #:
# COS20190010397
# --------
# Complaint #:
# COS20190011044
# --------
# Complaint #:
# COS20190003373
# --------
# Complaint #:
# COS20190010299
# --------
# Complaint #:
# COS20190013988
# --------
# Complaint #:
# COS20190012652
# --------
# Complaint #:
# COS20180015395
# --------
# Complaint #:
# COS20190010057
# --------
# Complaint #:
# COS20190010254
# --------
# Complaint #:
# COS20190000183
# --------
# Complaint #:
# COS20190010606
# --------
# Complaint #:
# COS20190010961
# --------
# Complaint #:
# COS20190010635
# --------
# Complaint #:
# COS20190014566
# --------
# Complaint #:
# COS20190010869
# --------
# Complaint #:
# COS20190007921
# --------
# Complaint #:
# COS20180009800
# --------
# Complaint #:
# COS20180011968
# --------
# Complaint #:
# COS20180014900
# --------
# Complaint #:
# COS20190008675
# --------
# Complaint #:
# COS20190009912
# --------
# Complaint #:
# COS20190011097
# --------
# Complaint #:
# County:
# --------
# Complaint #:
# COS20180012023
# --------
# Complaint #:
# COS20190008542
# --------
# Complaint #:
# COS20190009430
# --------
# Complaint #:
# COS20190009953
# --------
# Complaint #:
# COS20190010248
# --------
# Complaint #:
# COS20190008693
# --------
# Complaint #:
# COS20180016583
# --------
# Complaint #:
# COS20190001467
# --------
# Complaint #:
# COS20190008543
# --------
# Complaint #:
# COS20190005139
# --------
# Complaint #:
# COS20190010629
# --------
# Complaint #:
# COS20190010964
# --------
# Complaint #:
# COS20190011791
# --------
# Complaint #:
# COS20190012199
# --------
# Complaint #:
# County:
# --------
# Complaint #:
# COS20190003941
# --------
# Complaint #:
# COS20180004399
# --------
# Complaint #:
# COS20190001089
# --------
# Complaint #:
# COS20190007449
# --------
# Complaint #:
# COS20190002450
# --------
# Complaint #:
# COS20190005537
# --------
# Complaint #:
# County:
# --------
# Complaint #:
# COS20190001468
# --------
# Complaint #:
# COS20190003325
# --------
# Complaint #:
# COS20190006667
# --------
# Complaint #:
# COS20190005115
# --------
# Complaint #:
# COS20180011336
# --------
# Complaint #:
# COS20180002297
# --------
# Complaint #:
# COS20180015927
# --------
# Complaint #:
# COS20190000507
# --------
# Complaint #:
# COS20190001290
# --------
# Complaint #:
# COS20190002573
# --------
# Complaint #:
# COS20190003107
# --------
# Complaint #:
# COS20190005137
# --------
# Complaint #:
# COS20190005193
# --------
# Complaint #:
# COS20190002166
# --------
# Complaint #:
# COS20170022240
# --------
# Complaint #:
# COS20170016527
# --------
# Complaint #:
# COS20180003923
# --------
# Complaint #:
# COS20180016608
# --------
# Complaint #:
# COS20180016630
# --------
# Complaint #:
# COS20190001474
# --------
# Complaint #:
# COS20180008796
# --------
# Complaint #:
# COS20190005104
# --------
# Complaint #:
# COS20180013639
# --------
# Complaint #:
# COS20180014831
# --------
# Complaint #:
# COS20180016402
# --------
# Complaint #:
# COS20190001279
# --------
# Complaint #:
# COS20180016048
# --------
# Complaint #:
# COS20180016674
# --------
# Complaint #:
# COS20180016648
# --------
# Complaint #:
# COS20180015386
# --------
# Complaint #:
# COS20180016256
# --------
# Complaint #:
# COS20180003200
# --------
# Complaint #:
# COS20180011116
# --------
# Complaint #:
# COS20180016602
# --------
# Complaint #:
# COS20190001103
# --------
# Complaint #:
# COS20190001603
# --------
# Complaint #:
# COS20180015604
# --------
# Complaint #:
# COS20190000020
# --------
# Complaint #:
# COS20180014868
# --------
# Complaint #:
# COS20180010801
# --------
# Complaint #:
# COS20180011570
# --------
# Complaint #:
# COS20180009490
# --------
# Complaint #:
# COS20180014099
# --------
# Complaint #:
# COS20180007186
# --------
# Complaint #:
# COS20180011017
# --------
# Complaint #:
# COS20180014315
# --------
# Complaint #:
# COS20180015729
# --------
# Complaint #:
# COS20180012060
# --------
# Complaint #:
# COS20180014267
# --------
# Complaint #:
# COS20180012949
# --------
# Complaint #:
# COS20180014222
# --------
# Complaint #:
# COS20180010556
# --------
# Complaint #:
# COS20180014330
# --------
# Complaint #:
# COS20180007909
# --------
# Complaint #:
# COS20180008524
# --------
# Complaint #:
# COS20180011108
# --------
# Complaint #:
# COS20180013126
# --------
# Complaint #:
# COS20180008708
# --------
# Complaint #:
# COS20180008891
# --------
# Complaint #:
# COS20180012418
# --------
# Complaint #:
# COS20180015790
# --------
# Complaint #:
# COS20180013118
# --------
# Complaint #:
# COS20180012368
# --------
# Complaint #:
# COS20180006595
# --------
# Complaint #:
# COS20180007798
# --------
# Complaint #:
# COS2009004238D
# --------

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
results = []
for row in table_rows:
    try:
        name = row.find_element_by_class_name("results_text").text.strip()
        v_description = row.find_elements_by_tag_name("td")[2].text.strip()
        v_number = row.find_elements_by_tag_name("span")[10].text.strip()
        lic_number = row.find_elements_by_tag_name("span")[8].text.strip()
        zip_code = row.find_elements_by_tag_name("span")[6].text.strip()
        county = row.find_elements_by_tag_name("span")[4].text.strip()
        city = row.find_elements_by_tag_name("span")[2].text.strip()
        result = {
            'name': name,
            'v_description': v_description,
            'v_number': v_number,
            'lic_number': lic_number,
            'zip_code': zip_code,
            'county': county,
            'city': city,
        }
        results.append(result)
    except:
        pass
results
# Out:
# [{'name': 'NGUYEN, HUNG VU',
#   'v_description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to discard single use implements after each use; Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.',
#   'v_number': 'COS20190011025',
#   'lic_number': '730692',
#   'zip_code': '77086',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, MIMI PHAM',
#   'v_description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'v_number': 'COS20190010072',
#   'lic_number': '784210',
#   'zip_code': '77449',
#   'county': 'HARRIS',
#   'city': 'KATY'},
#  {'name': 'NGUYEN, HA',
#   'v_description': 'Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.',
#   'v_number': 'COS20190016762',
#   'lic_number': '764888',
#   'zip_code': '76017',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, THAO HONG',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20200010387',
#   'lic_number': '799926, 1753491',
#   'zip_code': '78238',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, MAI',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'v_number': 'COS20200007264',
#   'lic_number': '687294',
#   'zip_code': '75150',
#   'county': 'DALLAS',
#   'city': 'MESQUITE'},
#  {'name': 'NGUYEN, CINDY',
#   'v_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.',
#   'v_number': 'COS20200010502',
#   'lic_number': '806232, 1260359, 1280071',
#   'zip_code': '78414',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, CHAU KHANH LINH',
#   'v_description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'v_number': 'COS20190008104',
#   'lic_number': '1764073',
#   'zip_code': '36116',
#   'county': 'OUT OF STATE',
#   'city': 'MONTGOMERY'},
#  {'name': 'NGUYEN, TRANG T',
#   'v_description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.',
#   'v_number': 'COS20200010511',
#   'lic_number': '748483',
#   'zip_code': '78155',
#   'county': 'GUADALUPE',
#   'city': 'SEGUIN'},
#  {'name': 'NGUYEN, DUNG MINH',
#   'v_description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20200004202',
#   'lic_number': '785878',
#   'zip_code': '77066',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, YEN NHI THI',
#   'v_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.',
#   'v_number': 'COS20190004199',
#   'lic_number': '763645',
#   'zip_code': '78717',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, JOHNNY DAT',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.',
#   'v_number': 'COS20200000101',
#   'lic_number': '797651',
#   'zip_code': '78574',
#   'county': 'HIDALGO',
#   'city': 'MISSION'},
#  {'name': 'NGUYEN, KELLY PHUONG N',
#   'v_description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon.',
#   'v_number': 'COS20200011664',
#   'lic_number': '751553',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, NGA THU',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'v_number': 'COS20200010961',
#   'lic_number': '737176',
#   'zip_code': '77038',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, IVY',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'v_number': 'COS20200008858',
#   'lic_number': '772886',
#   'zip_code': '75092',
#   'county': 'GRAYSON',
#   'city': 'SHERMAN'},
#  {'name': 'NGUYEN, DIEMTRINH T',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20200008859',
#   'lic_number': '736591',
#   'zip_code': '75010',
#   'county': 'DALLAS',
#   'city': 'CARROLLTON'},
#  {'name': 'NGUYEN, HUAN CAO',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.',
#   'v_number': 'COS20200009732',
#   'lic_number': '786237',
#   'zip_code': '78229',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, THOA KIM',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20200006548',
#   'lic_number': '758361',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, TONY',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20200009605',
#   'lic_number': 'Not Licensed',
#   'zip_code': '78654',
#   'county': 'BURNET',
#   'city': 'MARBLE FALLS'},
#  {'name': 'NGUYEN, HIEN',
#   'v_description': 'Respondent failed to clean and disinfect all wax pots.',
#   'v_number': 'COS20190016479',
#   'lic_number': '801727',
#   'zip_code': '75605',
#   'county': 'GREGG',
#   'city': 'LONGVIEW'},
#  {'name': 'NGUYEN, NGOC TRAM',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190012148',
#   'lic_number': '712767',
#   'zip_code': '76137',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, TRAN NAM',
#   'v_description': 'Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'v_number': 'COS20190010318',
#   'lic_number': '733729',
#   'zip_code': '79015',
#   'county': 'RANDALL',
#   'city': 'CANYON'},
#  {'name': 'NGUYEN, PHILLIP',
#   'v_description': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.',
#   'v_number': 'COS20190014688',
#   'lic_number': '692372',
#   'zip_code': '79912',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, THUY T',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.',
#   'v_number': 'COS20190004016',
#   'lic_number': '794091',
#   'zip_code': '75007',
#   'county': 'DALLAS',
#   'city': 'CARROLLTON'},
#  {'name': 'NGUYEN, TRACY',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190016499',
#   'lic_number': '746762',
#   'zip_code': '76137',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, LE PHUC',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20200006146',
#   'lic_number': '739879',
#   'zip_code': '75048',
#   'county': 'COLLIN',
#   'city': 'SACHSE'},
#  {'name': 'NGUYEN, HAI MINH',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190016549',
#   'lic_number': '726039, 1110890',
#   'zip_code': '79936',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, TUYET',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190017217',
#   'lic_number': '774330, 1658860',
#   'zip_code': '75052',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, BA VAN',
#   'v_description': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.',
#   'v_number': 'COS20190016854',
#   'lic_number': '676940',
#   'zip_code': '76001',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, LAN THANH',
#   'v_description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'v_number': 'COS20190017175',
#   'lic_number': '766697',
#   'zip_code': '75216',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, PHUOC BA',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190013017',
#   'lic_number': '788725, 1552617',
#   'zip_code': '78250',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, LINH THUY KIEU',
#   'v_description': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.',
#   'v_number': 'COS20190016161',
#   'lic_number': '795480, 1700076',
#   'zip_code': '75044',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, TONY MINH',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20200000652',
#   'lic_number': '791638, 1124706',
#   'zip_code': '78654',
#   'county': 'BURNET',
#   'city': 'MARBLE FALLS'},
#  {'name': 'NGUYEN, THANH',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190007906',
#   'lic_number': '790672',
#   'zip_code': '75034',
#   'county': 'COLLIN',
#   'city': 'FRISCO'},
#  {'name': 'NGUYEN, HIEN THI MINH',
#   'v_description': 'Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.',
#   'v_number': 'COS20190003737',
#   'lic_number': '795179',
#   'zip_code': '77083',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, VAN NGOC THAO',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.',
#   'v_number': 'COS20190006118',
#   'lic_number': 'Not Licensed',
#   'zip_code': '75165',
#   'county': 'ELLIS',
#   'city': 'WAXAHACHIE'},
#  {'name': 'NGUYEN, TAM THANH',
#   'v_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'v_number': 'COS20200002642',
#   'lic_number': '1163702',
#   'zip_code': '76904',
#   'county': 'TOM GREEN',
#   'city': 'SAN ANGELO'},
#  {'name': 'NGUYEN, ANDY HUU',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'v_number': 'COS20190009211',
#   'lic_number': '776906, 1189873',
#   'zip_code': '76053',
#   'county': 'TARRANT',
#   'city': 'HURST'},
#  {'name': 'NGUYEN, CUONG HULL',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190010611',
#   'lic_number': '767705, 1094245',
#   'zip_code': '75052',
#   'county': 'TARRANT',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, NANCY HOA',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.',
#   'v_number': 'COS20190010665',
#   'lic_number': '785647, 1121812',
#   'zip_code': '75044',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, THOA THI KIM',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'v_number': 'COS20190001932',
#   'lic_number': '739510',
#   'zip_code': '78411',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, TRANG',
#   'v_description': 'Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.',
#   'v_number': 'COS20190014576',
#   'lic_number': '693311',
#   'zip_code': '75041',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, THONG VAN',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190001897',
#   'lic_number': '750663',
#   'zip_code': '79912',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, TUAN',
#   'v_description': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.",
#   'v_number': 'COS20190009239',
#   'lic_number': '783281',
#   'zip_code': '75237',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, LYNDA',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.',
#   'v_number': 'COS20190009484',
#   'lic_number': '781789',
#   'zip_code': '77449',
#   'county': 'HARRIS',
#   'city': 'KATY'},
#  {'name': 'NGUYEN, CATHY H',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'County:',
#   'lic_number': 'City:',
#   'zip_code': '78665',
#   'county': 'WILLIAMSON',
#   'city': 'ROUND ROCK'},
#  {'name': 'NGUYEN, PAMELA DAN',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.',
#   'v_number': 'COS20190011923',
#   'lic_number': '747589',
#   'zip_code': '78155',
#   'county': 'GUADALUPE',
#   'city': 'SEGUIN'},
#  {'name': 'NGUYEN, SON QUOC',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20190005539',
#   'lic_number': '772305, 1240974',
#   'zip_code': '76645',
#   'county': 'HILL',
#   'city': 'HILLSBORO'},
#  {'name': 'NGUYEN, KIM',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20190010176',
#   'lic_number': '786602',
#   'zip_code': '75240',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, THAI VAN',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190010397',
#   'lic_number': '797287, 1187211',
#   'zip_code': '75040',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, HANH THI',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20190011044',
#   'lic_number': '786707',
#   'zip_code': '77049',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, DIEP THI NGOC',
#   'v_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'v_number': 'COS20190003373',
#   'lic_number': '760528',
#   'zip_code': '77067',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, CASEY',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190010299',
#   'lic_number': '790137',
#   'zip_code': '77429',
#   'county': 'HARRIS',
#   'city': 'CYPRESS'},
#  {'name': 'NGUYEN, ANTHONY VAN',
#   'v_description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.",
#   'v_number': 'COS20190013988',
#   'lic_number': '750159',
#   'zip_code': '76117',
#   'county': 'TARRANT',
#   'city': 'HALTOM CITY'},
#  {'name': 'NGUYEN, CHRISTINA D',
#   'v_description': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190012652',
#   'lic_number': '716740',
#   'zip_code': '77642',
#   'county': 'JEFFERSON',
#   'city': 'PORT ARTHUR'},
#  {'name': 'NGUYEN, PHUONG T',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.',
#   'v_number': 'COS20180015395',
#   'lic_number': '748459',
#   'zip_code': '77083',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, KENNY',
#   'v_description': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190010057',
#   'lic_number': '75611',
#   'zip_code': '75232',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, THAO (MINH THAO',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190010254',
#   'lic_number': '785264',
#   'zip_code': '78644',
#   'county': 'CALDWELL',
#   'city': 'LOCKHART'},
#  {'name': 'NGUYEN, KENNY',
#   'v_description': 'Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20190000183',
#   'lic_number': '756711',
#   'zip_code': '75232',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, BA VAN',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190010606',
#   'lic_number': '720112',
#   'zip_code': '76063',
#   'county': 'TARRANT',
#   'city': 'MANSFIELD'},
#  {'name': 'NGUYEN, KHUYEN THI',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190010961',
#   'lic_number': '771681, 1442799',
#   'zip_code': '76117',
#   'county': 'TARRANT',
#   'city': 'HALTOM CITY'},
#  {'name': 'NGUYEN, SON DANG',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190010635',
#   'lic_number': '720091, 1195752',
#   'zip_code': '76119',
#   'county': 'TARRANT',
#   'city': 'FOREST HILL'},
#  {'name': 'NGUYEN, TUYEN THANH',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'v_number': 'COS20190014566',
#   'lic_number': '792178, 1468619, 1410422',
#   'zip_code': '76227',
#   'county': 'DENTON',
#   'city': 'AUBREY'},
#  {'name': 'NGUYEN, STEVEN THAI',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190010869',
#   'lic_number': '779635',
#   'zip_code': '75007',
#   'county': 'DALLAS',
#   'city': 'CARROLLTON'},
#  {'name': 'NGUYEN, CY VAN',
#   'v_description': 'Respondent operated a cosmetology salon without the appropriate license.',
#   'v_number': 'COS20190007921',
#   'lic_number': '765590',
#   'zip_code': '77007',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, QUANG DUC',
#   'v_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent stored chemicals in a restroom accessible to the public.',
#   'v_number': 'COS20180009800',
#   'lic_number': '749600, 1225146',
#   'zip_code': '79424',
#   'county': 'LUBBOCK',
#   'city': 'LUBBOCK'},
#  {'name': 'NGUYEN, OANH THI',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20180011968',
#   'lic_number': '770502',
#   'zip_code': '77351',
#   'county': 'POLK',
#   'city': 'LIVINGSTON'},
#  {'name': 'NGUYEN, AN QUY',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'v_number': 'COS20180014900',
#   'lic_number': '751433, 1083641',
#   'zip_code': '78249',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, HAU PHUC',
#   'v_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'v_number': 'COS20190008675',
#   'lic_number': '744770',
#   'zip_code': '78414',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, KIM LIEN THI',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190009912',
#   'lic_number': '713587',
#   'zip_code': '79107',
#   'county': 'POTTER',
#   'city': 'AMARILLO'},
#  {'name': 'NGUYEN, KENNY KHANH',
#   'v_description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.",
#   'v_number': 'COS20190011097',
#   'lic_number': '745308, 1419838',
#   'zip_code': '78641',
#   'county': 'WILLIAMSON',
#   'city': 'LEANDER'},
#  {'name': 'NGUYEN, KIM LAN THI',
#   'v_description': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used constitutes two violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.",
#   'v_number': 'County:',
#   'lic_number': 'City:',
#   'zip_code': '76901',
#   'county': 'TOM GREEN',
#   'city': 'SAN ANGELO'},
#  {'name': 'NGUYEN, DUONG VAN',
#   'v_description': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'v_number': 'COS20180012023',
#   'lic_number': '748281',
#   'zip_code': '75110',
#   'county': 'NAVARRO',
#   'city': 'CORSICANA'},
#  {'name': 'NGUYEN, HIEU CHAU',
#   'v_description': 'On two (2) occasions, Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190008542',
#   'lic_number': '777856',
#   'zip_code': '79938',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, TRANG KIM',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190009430',
#   'lic_number': '773798',
#   'zip_code': '77357',
#   'county': 'MONTGOMERY',
#   'city': 'NEW CANEY'},
#  {'name': 'NGUYEN, LINH H',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20190009953',
#   'lic_number': '78841, 1520821',
#   'zip_code': '78109',
#   'county': 'BEXAR',
#   'city': 'CONVERSE'},
#  {'name': 'NGUYEN, PHUONG DUC',
#   'v_description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.",
#   'v_number': 'COS20190010248',
#   'lic_number': '746023, 1244227, 1549650',
#   'zip_code': '79772',
#   'county': 'REEVES',
#   'city': 'PECOS'},
#  {'name': 'NGUYEN, NGUYET M',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190008693',
#   'lic_number': '724763, 1327682, 1148025',
#   'zip_code': '76116',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, VAN DO THI',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology with an expired license. Respondent operated a cosmetology salon without the appropriate license.',
#   'v_number': 'COS20180016583',
#   'lic_number': '749933, 1695846',
#   'zip_code': '75002',
#   'county': 'COLLIN',
#   'city': 'ALLEN'},
#  {'name': 'NGUYEN, XUAN THI',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20190001467',
#   'lic_number': '765777',
#   'zip_code': '77066',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, MICHAEL TAN',
#   'v_description': 'Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.',
#   'v_number': 'COS20190008543',
#   'lic_number': '751319, 1654218',
#   'zip_code': '78382',
#   'county': 'ARANSAS',
#   'city': 'ROCKPORT'},
#  {'name': 'NGUYEN, LANCHI',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20190005139',
#   'lic_number': 'Not Licensed',
#   'zip_code': '77015',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, DIEM',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20190010629',
#   'lic_number': '688282',
#   'zip_code': '75080',
#   'county': 'DALLAS',
#   'city': 'RICHARDSON'},
#  {'name': 'NGUYEN, LINH K',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190010964',
#   'lic_number': '678261, 871430',
#   'zip_code': '77072',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, THOANG THI',
#   'v_description': 'Respondent employed a person as an operator who did not hold a license.',
#   'v_number': 'COS20190011791',
#   'lic_number': '775443',
#   'zip_code': '77075',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, HOAI THU T',
#   'v_description': "Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.",
#   'v_number': 'COS20190012199',
#   'lic_number': '735244',
#   'zip_code': '79925',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, JIMMY DUC',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.',
#   'v_number': 'County:',
#   'lic_number': 'City:',
#   'zip_code': '76051',
#   'county': 'TARRANT',
#   'city': 'GRAPEVINE'},
#  {'name': 'NGUYEN, NINH VAN',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190003941',
#   'lic_number': '666588',
#   'zip_code': '75052',
#   'county': 'TARRANT',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, THANH HUU',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.',
#   'v_number': 'COS20180004399',
#   'lic_number': '745484, 1259159',
#   'zip_code': '75081',
#   'county': 'DALLAS',
#   'city': 'RICHARDSON'},
#  {'name': 'NGUYEN, UYEN THI TU',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20190001089',
#   'lic_number': 'Not Licensed',
#   'zip_code': '75904',
#   'county': 'ANGELINA',
#   'city': 'LUFKIN'},
#  {'name': 'NGUYEN, BANH THI',
#   'v_description': 'Respondent performed barbering without the required license.',
#   'v_number': 'COS20190007449',
#   'lic_number': 'Not Licensed',
#   'zip_code': '71854',
#   'county': 'OUT OF STATE',
#   'city': 'TEXARKANA'},
#  {'name': 'NGUYEN, KHIET THANH',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20190002450',
#   'lic_number': '710894',
#   'zip_code': '78413',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, SAM DUC',
#   'v_description': 'Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20190005537',
#   'lic_number': '772341, 1596452',
#   'zip_code': '78840',
#   'county': 'VAL VERDE',
#   'city': 'DEL RIO'},
#  {'name': 'NGUYEN, ANH HUU',
#   'v_description': 'Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots.',
#   'v_number': 'County:',
#   'lic_number': 'City:',
#   'zip_code': '75094',
#   'county': 'COLLIN',
#   'city': 'PLANO'},
#  {'name': 'NGUYEN, DIANE N',
#   'v_description': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'v_number': 'COS20190001468',
#   'lic_number': '681377, 1135046',
#   'zip_code': '76904',
#   'county': 'TOM GREEN',
#   'city': 'SAN ANGELO'},
#  {'name': 'NGUYEN, MICHAEL',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190003325',
#   'lic_number': '737006, 1155545',
#   'zip_code': '76014',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, CUONG TRAN',
#   'v_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'v_number': 'COS20190006667',
#   'lic_number': '1594001',
#   'zip_code': '76137',
#   'county': 'TARRANT',
#   'city': 'FORT WORTH'},
#  {'name': 'NGUYEN, TRAN NAM',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190005115',
#   'lic_number': '690490, 1143200',
#   'zip_code': '79015',
#   'county': 'RANDALL',
#   'city': 'CANYON'},
#  {'name': 'NGUYEN, TAMMY',
#   'v_description': 'Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'v_number': 'COS20180011336',
#   'lic_number': '781568, 1712086, 1234366, 1487516',
#   'zip_code': '79606',
#   'county': 'TAYLOR',
#   'city': 'ABILENE'},
#  {'name': 'NGUYEN, SUONG THI TRUC',
#   'v_description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'v_number': 'COS20180002297',
#   'lic_number': '1695256',
#   'zip_code': '74048',
#   'county': 'COLLIN',
#   'city': 'SACHSE'},
#  {'name': 'NGUYEN, THE THI',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20180015927',
#   'lic_number': '728111, 1097604, 1437455',
#   'zip_code': '79336',
#   'county': 'HOCKLEY',
#   'city': 'LEVELLAND'},
#  {'name': 'NGUYEN, KIMBERLY',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190000507',
#   'lic_number': '785284, 1516790',
#   'zip_code': '75604',
#   'county': 'GREGG',
#   'city': 'LONGVIEW'},
#  {'name': 'NGUYEN, DUY KINH',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'v_number': 'COS20190001290',
#   'lic_number': '765758, 1594533',
#   'zip_code': '78613',
#   'county': 'WILLIAMSON',
#   'city': 'CEDAR PARK'},
#  {'name': 'NGUYEN, LEENA L',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190002573',
#   'lic_number': '793631',
#   'zip_code': '79924',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, MAI TRANG',
#   'v_description': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190003107',
#   'lic_number': '792260, 1749538',
#   'zip_code': '75056',
#   'county': 'DENTON',
#   'city': 'THE COLONY'},
#  {'name': 'NGUYEN, HUYEN T',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190005137',
#   'lic_number': '774449, 1152042',
#   'zip_code': '77015',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, TUNG T',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20190005193',
#   'lic_number': '785431, 1667712',
#   'zip_code': '75703',
#   'county': 'SMITH',
#   'city': 'TYLER'},
#  {'name': 'NGUYEN, HIEN XUAN T',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190002166',
#   'lic_number': '741087',
#   'zip_code': '78248',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, TUYET',
#   'v_description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'v_number': 'COS20170022240',
#   'lic_number': '774330',
#   'zip_code': '75052',
#   'county': 'DALLAS',
#   'city': 'GRAND PRAIRIE'},
#  {'name': 'NGUYEN, HUYEN THI-MINH',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20170016527',
#   'lic_number': '732356, 1440217, 1529693',
#   'zip_code': '78727',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, HOA VAN',
#   'v_description': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.",
#   'v_number': 'COS20180003923',
#   'lic_number': '1216926',
#   'zip_code': '78753',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, PAUL',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20180016608',
#   'lic_number': '774054',
#   'zip_code': '75070',
#   'county': 'COLLIN',
#   'city': 'MCKINNEY'},
#  {'name': 'NGUYEN, LOAN HONG ANH',
#   'v_description': "Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.",
#   'v_number': 'COS20180016630',
#   'lic_number': '757086',
#   'zip_code': '76002',
#   'county': 'TARRANT',
#   'city': 'ARLINGTON'},
#  {'name': 'NGUYEN, MAI THI BACH',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190001474',
#   'lic_number': '725831',
#   'zip_code': '75172',
#   'county': 'DALLAS',
#   'city': 'WILMER'},
#  {'name': 'NGUYEN, TUYET-MAI PHAM',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20180008796',
#   'lic_number': '786753',
#   'zip_code': '75044',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, LIEN THI B',
#   'v_description': 'Respondent operated a cosmetology salon without the appropriate license; Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20190005104',
#   'lic_number': '794022',
#   'zip_code': '75601',
#   'county': 'GREGG',
#   'city': 'LONGVIEW'},
#  {'name': 'NGUYEN, MAI T',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20180013639',
#   'lic_number': '750076',
#   'zip_code': '78735',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, LIEN',
#   'v_description': 'Respondent failed to dispose of single use items after each use.',
#   'v_number': 'COS20180014831',
#   'lic_number': '746980',
#   'zip_code': '79109',
#   'county': 'POTTER',
#   'city': 'AMARILLO'},
#  {'name': 'NGUYEN, NGOC THI',
#   'v_description': 'Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'v_number': 'COS20180016402',
#   'lic_number': '737411, 1669514, 1140000, 1240416, 1562212',
#   'zip_code': '77072',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, VIET LINH',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20190001279',
#   'lic_number': 'Not Licensed',
#   'zip_code': '75092',
#   'county': 'GRAYSON',
#   'city': 'SHERMAN'},
#  {'name': 'NGUYEN, COURTNEY',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20180016048',
#   'lic_number': '745292',
#   'zip_code': '75757',
#   'county': 'SMITH',
#   'city': 'BULLARD'},
#  {'name': 'NGUYEN, TUYEN T',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'v_number': 'COS20180016674',
#   'lic_number': '790119, 767335, 1680828',
#   'zip_code': '77086',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, NHON A',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20180016648',
#   'lic_number': '734240',
#   'zip_code': '79745',
#   'county': 'WINKLER',
#   'city': 'KERMIT'},
#  {'name': 'NGUYEN, SOPHIE T',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20180015386',
#   'lic_number': '774072',
#   'zip_code': '79912',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, NGOC HONG THI',
#   'v_description': 'Respondent failed to properly disinfect implements at the end of each day.',
#   'v_number': 'COS20180016256',
#   'lic_number': '725673',
#   'zip_code': '77090',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, KHAN THI',
#   'v_description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.',
#   'v_number': 'COS20180003200',
#   'lic_number': '778045, 1290177',
#   'zip_code': '77833',
#   'county': 'WASHINGTON',
#   'city': 'BRENHAM'},
#  {'name': 'NGUYEN, ANNA AI',
#   'v_description': 'Respondent failed to clean and disinfect all wax pots.',
#   'v_number': 'COS20180011116',
#   'lic_number': '776928, 1475816',
#   'zip_code': '75024',
#   'county': 'COLLIN',
#   'city': 'PLANO'},
#  {'name': 'NGUYEN, NHU MAI',
#   'v_description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20180016602',
#   'lic_number': '745586',
#   'zip_code': '75024',
#   'county': 'COLLIN',
#   'city': 'PLANO'},
#  {'name': 'NGUYEN, DUNG QUANG',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20190001103',
#   'lic_number': '749917, 1165768',
#   'zip_code': '75206',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, MINH THU',
#   'v_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'v_number': 'COS20190001603',
#   'lic_number': '790174',
#   'zip_code': '79934',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, PHUONG THI',
#   'v_description': "Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day; Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.",
#   'v_number': 'COS20180015604',
#   'lic_number': '772550',
#   'zip_code': '77478',
#   'county': 'FORT BEND',
#   'city': 'SUGAR LAND'},
#  {'name': 'NGUYEN, CHARLIE',
#   'v_description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent failed to clean and disinfect all wax pots.",
#   'v_number': 'COS20190000020',
#   'lic_number': '763659',
#   'zip_code': '75219',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, HANH THI',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20180014868',
#   'lic_number': '761658',
#   'zip_code': '75237',
#   'county': 'DALLAS',
#   'city': 'DALLAS'},
#  {'name': 'NGUYEN, MINH V',
#   'v_description': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.',
#   'v_number': 'COS20180010801',
#   'lic_number': '745051',
#   'zip_code': '79928',
#   'county': 'EL PASO',
#   'city': 'HORIZON CITY'},
#  {'name': 'NGUYEN, NHAN THANH',
#   'v_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'v_number': 'COS20180011570',
#   'lic_number': '1265637',
#   'zip_code': '75040',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, THUYET',
#   'v_description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'v_number': 'COS20180009490',
#   'lic_number': '720045',
#   'zip_code': '78251',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, QUANG XUAN',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to properly disinfect implements at the end of each day.',
#   'v_number': 'COS20180014099',
#   'lic_number': '738063, 1231599',
#   'zip_code': '75180',
#   'county': 'DALLAS',
#   'city': 'BALCH SPRINGS'},
#  {'name': 'NGUYEN, TRUNG N',
#   'v_description': 'Respondent failed to dispose of single use items after each use.',
#   'v_number': 'COS20180007186',
#   'lic_number': '767014, 1196244',
#   'zip_code': '79106',
#   'county': 'POTTER',
#   'city': 'AMARILLO'},
#  {'name': 'NGUYEN, MYCAM THI',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20180011017',
#   'lic_number': '734788',
#   'zip_code': '75043',
#   'county': 'DALLAS',
#   'city': 'GARLAND'},
#  {'name': 'NGUYEN, THUYVI T',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20180014315',
#   'lic_number': '784702',
#   'zip_code': '78660',
#   'county': 'TRAVIS',
#   'city': 'PFLUGERVILLE'},
#  {'name': 'NGUYEN, OANH PHUONG',
#   'v_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'v_number': 'COS20180015729',
#   'lic_number': '739546',
#   'zip_code': '76542',
#   'county': 'BELL',
#   'city': 'KILLEEN'},
#  {'name': 'NGUYEN, QUANG Q',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'v_number': 'COS20180012060',
#   'lic_number': '771954',
#   'zip_code': '88008',
#   'county': 'OUT OF STATE',
#   'city': 'SANTA TERESA'},
#  {'name': 'NGUYEN, CINDY',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to ensure that only semi-permanent glue was used during eyelash extension services.',
#   'v_number': 'COS20180014267',
#   'lic_number': '786409',
#   'zip_code': '78414',
#   'county': 'NUECES',
#   'city': 'CORPUS CHRISTI'},
#  {'name': 'NGUYEN, KEVIN HOA',
#   'v_description': "Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.",
#   'v_number': 'COS20180012949',
#   'lic_number': '746655',
#   'zip_code': '91770',
#   'county': 'OUT OF STATE',
#   'city': 'ROSEMEAD'},
#  {'name': 'NGUYEN, THUY T',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20180014222',
#   'lic_number': '720854',
#   'zip_code': '78003',
#   'county': 'BANDERA',
#   'city': 'BANDERA'},
#  {'name': 'NGUYEN, THIENTRANG THI',
#   'v_description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'v_number': 'COS20180010556',
#   'lic_number': '783069, 1655219',
#   'zip_code': '78735',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, MARY ANN',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20180014330',
#   'lic_number': 'Not Licensed',
#   'zip_code': '78660',
#   'county': 'TRAVIS',
#   'city': 'PFLUGERVILLE'},
#  {'name': 'NGUYEN, THANH CHUONG',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20180007909',
#   'lic_number': '748957, 1340920',
#   'zip_code': '75048',
#   'county': 'COLLIN',
#   'city': 'SACHSE'},
#  {'name': 'NGUYEN, PHUONG N',
#   'v_description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'v_number': 'COS20180008524',
#   'lic_number': '1199884, 1706073',
#   'zip_code': '77474',
#   'county': 'AUSTIN',
#   'city': 'SEALY'},
#  {'name': 'NGUYEN, ANH TRAM',
#   'v_description': 'Respondent failed to dispose of single use items after each use.',
#   'v_number': 'COS20180011108',
#   'lic_number': '759616, 1475221, 1521294',
#   'zip_code': '77089',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'},
#  {'name': 'NGUYEN, HIEN',
#   'v_description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'v_number': 'COS20180013126',
#   'lic_number': 'Not Licensed',
#   'zip_code': '78602',
#   'county': 'BASTROP',
#   'city': 'BASTROP'},
#  {'name': 'NGUYEN, TUAN A',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'v_number': 'COS20180008708',
#   'lic_number': '681274',
#   'zip_code': '78723',
#   'county': 'TRAVIS',
#   'city': 'AUSTIN'},
#  {'name': 'NGUYEN, LEON A',
#   'v_description': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of a crime that was committed within 5 years of their renewal application; Respondent lacks sufficient honesty, trustworthiness and integrity to hold a license.",
#   'v_number': 'COS20180008891',
#   'lic_number': '1173346',
#   'zip_code': '75048',
#   'county': 'COLLIN',
#   'city': 'SACHSE'},
#  {'name': 'NGUYEN, VINH QUANG',
#   'v_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'v_number': 'COS20180012418',
#   'lic_number': '712441',
#   'zip_code': '79901',
#   'county': 'EL PASO',
#   'city': 'EL PASO'},
#  {'name': 'NGUYEN, BINH VAN',
#   'v_description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'v_number': 'COS20180015790',
#   'lic_number': '756644',
#   'zip_code': '76543',
#   'county': 'BELL',
#   'city': 'KILLEEN'},
#  {'name': 'NGUYEN, SHARON',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'v_number': 'COS20180013118',
#   'lic_number': '750030',
#   'zip_code': '78602',
#   'county': 'BASTROP',
#   'city': 'BASTROP'},
#  {'name': 'NGUYEN, BINH THANH',
#   'v_description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'v_number': 'COS20180012368',
#   'lic_number': '772744',
#   'zip_code': '78045',
#   'county': 'WEBB',
#   'city': 'LAREDO'},
#  {'name': 'NGUYEN, SAMANTHA TRAN',
#   'v_description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'v_number': 'COS20180006595',
#   'lic_number': '743492, 1279657, 1562243',
#   'zip_code': '75070',
#   'county': 'COLLIN',
#   'city': 'MCKINNEY'},
#  {'name': 'NGUYEN, THU LE',
#   'v_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'v_number': 'COS20180007798',
#   'lic_number': '11224436, 685119',
#   'zip_code': '78216',
#   'county': 'BEXAR',
#   'city': 'SAN ANTONIO'},
#  {'name': 'NGUYEN, KIM NGAN THI',
#   'v_description': 'Respondent interfered with a Department inspection of the salon.',
#   'v_number': 'COS2009004238D',
#   'lic_number': '1434311',
#   'zip_code': '77084',
#   'county': 'HARRIS',
#   'city': 'HOUSTON'}]

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: Use `pd.DataFrame` to create a dataframe, and then save it to a CSV.

# %%
import pandas as pd
df = pd.DataFrame(results)
df.head()
# Out:
# /Users/khanfazil/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                 name                                      v_description  \
# 0    NGUYEN, HUNG VU  Respondent failed properly clean and sanitize ...
# 1  NGUYEN, MIMI PHAM  Respondent failed properly clean and sanitize ...
# 2         NGUYEN, HA  Respondent failed to clean and sanitize four (...
# 3  NGUYEN, THAO HONG  Respondent failed to clean, disinfect, and ste...
# 4        NGUYEN, MAI  Respondent failed to clean, disinfect, and ste...
#
#          v_number       lic_number zip_code   county         city
# 0  COS20190011025           730692    77086   HARRIS      HOUSTON
# 1  COS20190010072           784210    77449   HARRIS         KATY
# 2  COS20190016762           764888    76017  TARRANT    ARLINGTON
# 3  COS20200010387  799926, 1753491    78238    BEXAR  SAN ANTONIO
# 4  COS20200007264           687294    75150   DALLAS     MESQUITE

# %%
df.to_csv("texas_cosmet.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df1 = pd.read_csv("texas_cosmet.csv")
df1.head()
# Out:
#                 name                                      v_description  \
# 0    NGUYEN, HUNG VU  Respondent failed properly clean and sanitize ...
# 1  NGUYEN, MIMI PHAM  Respondent failed properly clean and sanitize ...
# 2         NGUYEN, HA  Respondent failed to clean and sanitize four (...
# 3  NGUYEN, THAO HONG  Respondent failed to clean, disinfect, and ste...
# 4        NGUYEN, MAI  Respondent failed to clean, disinfect, and ste...
#
#          v_number       lic_number  zip_code   county         city
# 0  COS20190011025           730692     77086   HARRIS      HOUSTON
# 1  COS20190010072           784210     77449   HARRIS         KATY
# 2  COS20190016762           764888     76017  TARRANT    ARLINGTON
# 3  COS20200010387  799926, 1753491     78238    BEXAR  SAN ANTONIO
# 4  COS20200007264           687294     75150   DALLAS     MESQUITE

# %% [markdown]
# ## Let's do this an easier way
#
# Use Selenium and `pd.read_html` to get the table as a dataframe.

# %%
import lxml
from bs4 import BeautifulSoup

# %%
table = pd.read_html(driver.page_source)
table[0]
# Out:
#                                      Name and Location  \
# 0    NGUYEN, HUNG VU City: HOUSTON County: HARRIS Z...
# 1    NGUYEN, MIMI PHAM City: KATY County: HARRIS Zi...
# 2    NGUYEN, HA City: ARLINGTON County: TARRANT Zip...
# 3    NGUYEN, THAO HONG City: SAN ANTONIO County: BE...
# 4    NGUYEN, MAI City: MESQUITE County: DALLAS Zip ...
# ..                                                 ...
# 154  NGUYEN, SHARON City: BASTROP County: BASTROP Z...
# 155  NGUYEN, BINH THANH City: LAREDO County: WEBB Z...
# 156  NGUYEN, SAMANTHA TRAN City: MCKINNEY County: C...
# 157  NGUYEN, THU LE City: SAN ANTONIO County: BEXAR...
# 158  NGUYEN, KIM NGAN THI City: HOUSTON County: HAR...
#
#                                                  Order  \
# 0    Date: 11/24/2020Respondent is assessed an admi...
# 1    Date: 11/12/2020Respondent is assessed an admi...
# 2    Date: 11/12/2020Respondent is assessed an admi...
# 3    Date: 11/12/2020Respondent is assessed an admi...
# 4    Date: 10/29/2020Respondent is assessed an admi...
# ..                                                 ...
# 154  Date: 9/17/2018Respondent is assessed an admin...
# 155  Date: 9/12/2018Respondent is assessed an admin...
# 156  Date: 9/4/2018Respondent is assessed an admini...
# 157  Date: 8/7/2018The Respondent's Cosmetology Man...
# 158  Date: 12/9/2009Respondent is assessed an admin...
#
#                                        Basis for Order
# 0    Respondent failed properly clean and sanitize ...
# 1    Respondent failed properly clean and sanitize ...
# 2    Respondent failed to clean and sanitize four (...
# 3    Respondent failed to clean, disinfect, and ste...
# 4    Respondent failed to clean, disinfect, and ste...
# ..                                                 ...
# 154  Respondent leased space in a salon to an indiv...
# 155  Respondent leased space in a salon to an indiv...
# 156  Respondent failed to clean, disinfect, and ste...
# 157  Respondent failed to comply with an order prev...
# 158  Respondent interfered with a Department inspec...
#
# [159 rows x 3 columns]
