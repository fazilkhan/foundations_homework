# %% [markdown]
# ##DC Inbox - Algos Assignment##

# %%
import pandas as pd

pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 100)
# Out:
# /Users/khanfazil/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv("04_2020.csv")

# %%
df.head()
# Out:
#             Date  \
# 0  4/30/20 19:47
# 1  4/30/20 19:32
# 2  4/30/20 18:41
# 3  4/30/20 18:40
# 4  4/30/20 18:20
#
#                                                                                                     Subject  \
# 0  Fincantieri Marinette Marine Wins Guided-Missile Frigate Contract, Major Win For Upper Peninsula Workers
# 1                                                         April 30: A Doctor's Note on Coronavirus in TX-26
# 2                                                                          COVID-19 Update | April 30, 2020
# 3                Congresswoman Beatty Recognizes Front Line Workers and Connects With Central Ohio Seniors
# 4                                                                NEW UPDATE: Expanded Unemployment Benefits
#
#                                                                                                                                                                                                    Message  \
# 0    \n￼\n\nFOR IMMEDIATE RELEASE:  \nApril 30, 2020\nCONTACT:\nJames Hogge 231-640-9158\n\n\nFincantieri Marinette Marine Wins Guided-Missile Frigate Contract, Major Win For Upper Peninsula Workers\...
# 1  ￼\nApril 30, 2020
#
# Dear Friends,
#
# Tonight, I will be hosting a tele-townhall about this Coronavirus Pandemic. My intention is to hear first-hand from Texas-26 and how they have been affected by th...
# 2  COVID-19 Update | April 30, 2020\nView Email in Browser \n￼ \nDear Friends,\n\nAs we come to the end of National Child Abuse Prevention Month, it is important that we remain vigilant to protect th...
# 3  ￼\n￼\n￼\n￼\n￼\n￼\n￼\n￼\nCongresswoman Beatty Recognizes Front Line Workers and Connects With Central Ohio Seniors \nU.S. Congresswoman Joyce Beatty (OH-03) and her staff recently sent cards and th...
# 4  ￼  \nDear Friend,
#
# Report after report is highlighting what families in every corner of Oregon already know firsthand: The economic impacts of the coronavirus are dire, with big implications for ...
#
#   bioguide_id
# 0     B001301
# 1     B001248
# 2     H001072
# 3     B001281
# 4     M001176

# %%
df.shape
# Out:
# (2374, 4)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import lxml
driver = webdriver.Chrome()

# %%
driver.get("https://www.congress.gov/help/field-values/member-bioguide-ids")

# %%
table_rows = driver.find_elements_by_tag_name('tbody')

# %%
for row in table_rows:
    row_list = row.find_elements_by_tag_name('tr')

# %%
row_list[1].find_element_by_tag_name('td').text.strip()
# Out:
# 'Abdnor, James (Republican - South Dakota)'

# %%
congress_IDs = []
for row in row_list:
    try:
        member_name = row.find_elements_by_tag_name('td')[0].text.strip()
        member_id = row.find_elements_by_tag_name('td')[1].text.strip()
    except:
        pass
        results = {
            'member_name': member_name,
            'member_id': member_id
        }
        congress_IDs.append(results)
congress_IDs
# Out:
# [{'member_name': 'Abraham, Spencer (Republican - Michigan)',
#   'member_id': 'A000355'},
#  {'member_name': 'Abdnor, James (Republican - South Dakota)',
#   'member_id': 'A000009'},
#  {'member_name': 'Abercrombie, Neil (Democratic - Hawaii)',
#   'member_id': 'A000014'},
#  {'member_name': 'Abourezk, James (Democratic - South Dakota)',
#   'member_id': 'A000017'},
#  {'member_name': 'Abraham, Ralph Lee (Republican - Louisiana)',
#   'member_id': 'A000374'},
#  {'member_name': 'Abraham, Spencer (Republican - Michigan)',
#   'member_id': 'A000355'},
#  {'member_name': 'Abzug, Bella S. (Democratic - New York)',
#   'member_id': 'A000018'},
#  {'member_name': 'Acevedo-Vila, Anibal (Democratic - Puerto Rico)',
#   'member_id': 'A000359'},
#  {'member_name': 'Ackerman, Gary L. (Democratic - New York)',
#   'member_id': 'A000022'},
#  {'member_name': 'Adams, Alma S. (Democratic - North Carolina)',
#   'member_id': 'A000370'},
#  {'member_name': 'Adams, Brock (Democratic - Washington)',
#   'member_id': 'A000031'},
#  {'member_name': 'Adams, Sandy (Republican - Florida)',
#   'member_id': 'A000366'},
#  {'member_name': 'Addabbo, Joseph P. (Democratic - New York)',
#   'member_id': 'A000052'},
#  {'member_name': 'Aderholt, Robert B. (Republican - Alabama)',
#   'member_id': 'A000055'},
#  {'member_name': 'Adler, John H. (Democratic - New Jersey)',
#   'member_id': 'A000364'},
#  {'member_name': 'Aguilar, Pete (Democratic - California)',
#   'member_id': 'A000371'},
#  {'member_name': 'Aiken, George (Republican - Vermont)',
#   'member_id': 'A000062'},
#  {'member_name': 'Akaka, Daniel K. (Democratic - Hawaii)',
#   'member_id': 'A000069'},
#  {'member_name': 'Akin, W. Todd (Republican - Missouri)',
#   'member_id': 'A000358'},
#  {'member_name': 'Albert, Carl (Democratic - Oklahoma)',
#   'member_id': 'A000073'},
#  {'member_name': 'Albosta, Donald J. (Democratic - Michigan)',
#   'member_id': 'A000076'},
#  {'member_name': 'Alexander, Bill (Democratic - Arkansas)',
#   'member_id': 'A000103'},
#  {'member_name': 'Alexander, Lamar (Republican - Tennessee)',
#   'member_id': 'A000360'},
#  {'member_name': 'Alexander, Rodney (Republican - Louisiana)',
#   'member_id': 'A000361'},
#  {'member_name': 'Allard, Wayne (Republican - Colorado)',
#   'member_id': 'A000109'},
#  {'member_name': 'Allen, Clifford R. (Democratic - Tennessee)',
#   'member_id': 'A000118'},
#  {'member_name': 'Allen, George (Republican - Virginia)',
#   'member_id': 'A000121'},
#  {'member_name': 'Allen, James B. (Democratic - Alabama)',
#   'member_id': 'A000127'},
#  {'member_name': 'Allen, Maryon (Democratic - Alabama)',
#   'member_id': 'A000139'},
#  {'member_name': 'Allen, Rick W. (Republican - Georgia)',
#   'member_id': 'A000372'},
#  {'member_name': 'Allen, Thomas H. (Democratic - Maine)',
#   'member_id': 'A000357'},
#  {'member_name': 'Allred, Colin Z. (Democratic - Texas)',
#   'member_id': 'A000376'},
#  {'member_name': 'Altmire, Jason (Democratic - Pennsylvania)',
#   'member_id': 'A000362'},
#  {'member_name': 'Amash, Justin (Libertarian - Michigan)',
#   'member_id': 'A000367'},
#  {'member_name': 'Ambro, Jerome A. (Democratic - New York)',
#   'member_id': 'A000170'},
#  {'member_name': 'Ammerman, Joseph S. (Democratic - Pennsylvania)',
#   'member_id': 'A000177'},
#  {'member_name': 'Amodei, Mark E. (Republican - Nevada)',
#   'member_id': 'A000369'},
#  {'member_name': 'Anderson, Glenn M. (Democratic - California)',
#   'member_id': 'A000189'},
#  {'member_name': 'Anderson, John B. (Republican - Illinois)',
#   'member_id': 'A000195'},
#  {'member_name': 'Anderson, Wendell R. (Democratic - Minnesota)',
#   'member_id': 'A000202'},
#  {'member_name': 'Andrews, Ike (Democratic - North Carolina)',
#   'member_id': 'A000207'},
#  {'member_name': 'Andrews, Mark (Republican - North Dakota)',
#   'member_id': 'A000208'},
#  {'member_name': 'Andrews, Michael (Democratic - Texas)',
#   'member_id': 'A000209'},
#  {'member_name': 'Andrews, Robert E. (Democratic - New Jersey)',
#   'member_id': 'A000210'},
#  {'member_name': 'Andrews, Thomas H. (Democratic - Maine)',
#   'member_id': 'A000211'},
#  {'member_name': 'Annunzio, Frank (Democratic - Illinois)',
#   'member_id': 'A000212'},
#  {'member_name': 'Anthony, Beryl, Jr. (Democratic - Arkansas)',
#   'member_id': 'A000213'},
#  {'member_name': 'Applegate, Douglas (Democratic - Ohio)',
#   'member_id': 'A000214'},
#  {'member_name': 'Archer, Bill (Republican - Texas)', 'member_id': 'A000215'},
#  {'member_name': 'Arcuri, Michael A. (Democratic - New York)',
#   'member_id': 'A000363'},
#  {'member_name': 'Arends, Leslie C. (Republican - Illinois)',
#   'member_id': 'A000216'},
#  {'member_name': 'Armey, Richard K. (Republican - Texas)',
#   'member_id': 'A000217'},
#  {'member_name': 'Armstrong, Kelly (Republican - North Dakota)',
#   'member_id': 'A000377'},
#  {'member_name': 'Armstrong, William L. (Republican - Colorado)',
#   'member_id': 'A000219'},
#  {'member_name': 'Arrington, Jodey C. (Republican - Texas)',
#   'member_id': 'A000375'},
#  {'member_name': 'Ashbrook, Jean (Republican - Ohio)', 'member_id': 'A000220'},
#  {'member_name': 'Ashbrook, John M. (Republican - Ohio)',
#   'member_id': 'A000221'},
#  {'member_name': 'Ashcroft, John (Republican - Missouri)',
#   'member_id': 'A000356'},
#  {'member_name': 'Ashford, Brad (Democratic - Nebraska)',
#   'member_id': 'A000373'},
#  {'member_name': 'Ashley, Thomas L. (Democratic - Ohio)',
#   'member_id': 'A000222'},
#  {'member_name': 'Aspin, Les (Democratic - Wisconsin)',
#   'member_id': 'A000224'},
#  {'member_name': 'Atkins, Chester G. (Democratic - Massachusetts)',
#   'member_id': 'A000226'},
#  {'member_name': 'Atkinson, Eugene V. (Democratic - Pennsylvania)',
#   'member_id': 'A000329'},
#  {'member_name': 'Auchincloss, Jake (Democratic - Massachusetts)',
#   'member_id': 'A000148'},
#  {'member_name': 'AuCoin, Les (Democratic - Oregon)', 'member_id': 'A000337'},
#  {'member_name': 'Austria, Steve (Republican - Ohio)', 'member_id': 'A000365'},
#  {'member_name': 'Axne, Cynthia (Democratic - Iowa)', 'member_id': 'A000378'},
#  {'member_name': 'Ayotte, Kelly (Republican - New Hampshire)',
#   'member_id': 'A000368'},
#  {'member_name': 'Babin, Brian (Republican - Texas)', 'member_id': 'B001291'},
#  {'member_name': 'Baca, Joe (Democratic - California)',
#   'member_id': 'B001234'},
#  {'member_name': 'Bacchus, Jim (Democratic - Florida)',
#   'member_id': 'B000008'},
#  {'member_name': 'Bachmann, Michele (Republican - Minnesota)',
#   'member_id': 'B001256'},
#  {'member_name': 'Bachus, Spencer (Republican - Alabama)',
#   'member_id': 'B000013'},
#  {'member_name': 'Bacon, Don (Republican - Nebraska)', 'member_id': 'B001298'},
#  {'member_name': 'Badham, Robert E. (Republican - California)',
#   'member_id': 'B000024'},
#  {'member_name': 'Badillo, Herman (Democratic - New York)',
#   'member_id': 'B000025'},
#  {'member_name': 'Baesler, Scotty (Democratic - Kentucky)',
#   'member_id': 'B000028'},
#  {'member_name': 'Bafalis, L. A. (Skip) (Republican - Florida)',
#   'member_id': 'B000029'},
#  {'member_name': 'Bailey, Donald A. (Democratic - Pennsylvania)',
#   'member_id': 'B000037'},
#  {'member_name': 'Bailey, Wendell (Republican - Missouri)',
#   'member_id': 'B000047'},
#  {'member_name': 'Baird, Brian (Democratic - Washington)',
#   'member_id': 'B001229'},
#  {'member_name': 'Baird, James R. (Republican - Indiana)',
#   'member_id': 'B001307'},
#  {'member_name': 'Baker, Bill (Republican - California)',
#   'member_id': 'B000078'},
#  {'member_name': 'Baker, Howard H., Jr. (Republican - Tennessee)',
#   'member_id': 'B000063'},
#  {'member_name': 'Baker, LaMar (Republican - Tennessee)',
#   'member_id': 'B000069'},
#  {'member_name': 'Baker, Richard H. (Republican - Louisiana)',
#   'member_id': 'B000072'},
#  {'member_name': 'Baldacci, John Elias (Democratic - Maine)',
#   'member_id': 'B000081'},
#  {'member_name': 'Balderson, Troy (Republican - Ohio)',
#   'member_id': 'B001306'},
#  {'member_name': 'Baldus, Alvin J. (Democratic - Wisconsin)',
#   'member_id': 'B000083'},
#  {'member_name': 'Baldwin, Tammy (Democratic - Wisconsin)',
#   'member_id': 'B001230'},
#  {'member_name': 'Ballance, Frank W., Jr. (Democratic - North Carolina)',
#   'member_id': 'B001238'},
#  {'member_name': 'Ballenger, Cass (Republican - North Carolina)',
#   'member_id': 'B000104'},
#  {'member_name': 'Banks, Jim (Republican - Indiana)', 'member_id': 'B001299'},
#  {'member_name': 'Barber, Ron (Democratic - Arizona)', 'member_id': 'B001279'},
#  {'member_name': 'Barca, Peter (Democratic - Wisconsin)',
#   'member_id': 'B001226'},
#  {'member_name': 'Barcia, James A. (Democratic - Michigan)',
#   'member_id': 'B000134'},
#  {'member_name': 'Barkley, Dean M. (Independent - Minnesota)',
#   'member_id': 'B001237'},
#  {'member_name': 'Barletta, Lou (Republican - Pennsylvania)',
#   'member_id': 'B001269'},
#  {'member_name': 'Barlow, Tom (Democratic - Kentucky)',
#   'member_id': 'B000151'},
#  {'member_name': 'Barnard, Doug, Jr. (Democratic - Georgia)',
#   'member_id': 'B000153'},
#  {'member_name': 'Barnes, Michael D. (Democratic - Maryland)',
#   'member_id': 'B000160'},
#  {'member_name': 'Barr, Andy (Republican - Kentucky)', 'member_id': 'B001282'},
#  {'member_name': 'Barr, Bob (Republican - Georgia)', 'member_id': 'B000169'},
#  {'member_name': 'Barragan, Nanette Diaz (Democratic - California)',
#   'member_id': 'B001300'},
#  {'member_name': 'Barrasso, John (Republican - Wyoming)',
#   'member_id': 'B001261'},
#  {'member_name': 'Barrett, Bill (Republican - Nebraska)',
#   'member_id': 'B000179'},
#  {'member_name': 'Barrett, J. Gresham (Republican - South Carolina)',
#   'member_id': 'B001239'},
#  {'member_name': 'Barrett, Thomas M. (Democratic - Wisconsin)',
#   'member_id': 'B000177'},
#  {'member_name': 'Barrett, William A. (Democratic - Pennsylvania)',
#   'member_id': 'B000178'},
#  {'member_name': 'Barrow, John (Democratic - Georgia)',
#   'member_id': 'B001252'},
#  {'member_name': 'Bartlett, Dewey F. (Republican - Oklahoma)',
#   'member_id': 'B000200'},
#  {'member_name': 'Bartlett, Roscoe G. (Republican - Maryland)',
#   'member_id': 'B000208'},
#  {'member_name': 'Bartlett, Steve (Republican - Texas)',
#   'member_id': 'B000204'},
#  {'member_name': 'Barton, Joe (Republican - Texas)', 'member_id': 'B000213'},
#  {'member_name': 'Bass, Charles F. (Republican - New Hampshire)',
#   'member_id': 'B000220'},
#  {'member_name': 'Bass, Karen (Democratic - California)',
#   'member_id': 'B001270'},
#  {'member_name': 'Bateman, Herbert H. (Republican - Virginia)',
#   'member_id': 'B000229'},
#  {'member_name': 'Bates, Jim (Democratic - California)',
#   'member_id': 'B000236'},
#  {'member_name': 'Baucus, Max (Democratic - Montana)', 'member_id': 'B000243'},
#  {'member_name': 'Bauman, Robert E. (Republican - Maryland)',
#   'member_id': 'B000244'},
#  {'member_name': 'Bayh, Birch (Democratic - Indiana)', 'member_id': 'B000254'},
#  {'member_name': 'Bayh, Evan (Democratic - Indiana)', 'member_id': 'B001233'},
#  {'member_name': 'Beall, J. Glenn, Jr. (Republican - Maryland)',
#   'member_id': 'B000272'},
#  {'member_name': 'Bean, Melissa L. (Democratic - Illinois)',
#   'member_id': 'B001253'},
#  {'member_name': 'Beard, Edward (Democratic - Rhode Island)',
#   'member_id': 'B000279'},
#  {'member_name': 'Beard, Robin (Republican - Tennessee)',
#   'member_id': 'B000280'},
#  {'member_name': 'Beatty, Joyce (Democratic - Ohio)', 'member_id': 'B001281'},
#  {'member_name': 'Beauprez, Bob (Republican - Colorado)',
#   'member_id': 'B001240'},
#  {'member_name': 'Becerra, Xavier (Democratic - California)',
#   'member_id': 'B000287'},
#  {'member_name': 'Bedell, Berkley W. (Democratic - Iowa)',
#   'member_id': 'B000298'},
#  {'member_name': 'Begich, Mark (Democratic - Alaska)', 'member_id': 'B001265'},
#  {'member_name': 'Beilenson, Anthony C. (Democratic - California)',
#   'member_id': 'B000318'},
#  {'member_name': 'Bell, Alphonzo (Republican - California)',
#   'member_id': 'B000330'},
#  {'member_name': 'Bell, Chris (Democratic - Texas)', 'member_id': 'B001241'},
#  {'member_name': 'Bellmon, Henry L. (Republican - Oklahoma)',
#   'member_id': 'B000351'},
#  {'member_name': 'Benedict, Cleve (Republican - West Virginia)',
#   'member_id': 'B000358'},
#  {'member_name': 'Benishek, Dan (Republican - Michigan)',
#   'member_id': 'B001271'},
#  {'member_name': 'Benitez, Jamie (Democratic - Puerto Rico)',
#   'member_id': 'B000362'},
#  {'member_name': 'Benjamin, Adam, Jr. (Democratic - Indiana)',
#   'member_id': 'B000363'},
#  {'member_name': 'Bennet, Michael F. (Democratic - Colorado)',
#   'member_id': 'B001267'},
#  {'member_name': 'Bennett, Charles E. (Democratic - Florida)',
#   'member_id': 'B000371'},
#  {'member_name': 'Bennett, Robert F. (Republican - Utah)',
#   'member_id': 'B000382'},
#  {'member_name': 'Bennett, Wallace F. (Republican - Utah)',
#   'member_id': 'B000384'},
#  {'member_name': 'Bentivolio, Kerry L. (Republican - Michigan)',
#   'member_id': 'B001280'},
#  {'member_name': 'Bentley, Helen Delich (Republican - Maryland)',
#   'member_id': 'B000392'},
#  {'member_name': 'Bentsen, Ken (Democratic - Texas)', 'member_id': 'B000400'},
#  {'member_name': 'Bentsen, Lloyd M. (Democratic - Texas)',
#   'member_id': 'B000401'},
#  {'member_name': 'Bentz, Cliff (Republican - Oregon)', 'member_id': 'B000668'},
#  {'member_name': 'Bera, Ami (Democratic - California)',
#   'member_id': 'B001287'},
#  {'member_name': 'Bereuter, Doug (Republican - Nebraska)',
#   'member_id': 'B000403'},
#  {'member_name': 'Berg, Rick (Republican - North Dakota)',
#   'member_id': 'B001272'},
#  {'member_name': 'Bergland, Bob (Republican - Minnesota)',
#   'member_id': 'B000408'},
#  {'member_name': 'Bergman, Jack (Republican - Michigan)',
#   'member_id': 'B001301'},
#  {'member_name': 'Berkley, Shelley (Democratic - Nevada)',
#   'member_id': 'B001231'},
#  {'member_name': 'Berman, Howard L. (Democratic - California)',
#   'member_id': 'B000410'},
#  {'member_name': 'Berry, Marion (Democratic - Arkansas)',
#   'member_id': 'B000420'},
#  {'member_name': 'Bethune, Ed (Republican - Arkansas)',
#   'member_id': 'B000422'},
#  {'member_name': 'Bevill, Tom (Democratic - Alabama)', 'member_id': 'B000431'},
#  {'member_name': 'Beyer, Donald S., Jr. (Democratic - Virginia)',
#   'member_id': 'B001292'},
#  {'member_name': 'Biaggi, Mario (Democratic - New York)',
#   'member_id': 'B000432'},
#  {'member_name': 'Bible, Alan (Democratic - Nevada)', 'member_id': 'B000436'},
#  {'member_name': 'Bice, Stephanie I. (Republican - Oklahoma)',
#   'member_id': 'B000740'},
#  {'member_name': 'Biden, Joseph R., Jr. (Democratic - Delaware)',
#   'member_id': 'B000444'},
#  {'member_name': 'Biester, Edward G., Jr. (Republican - Pennsylvania)',
#   'member_id': 'B000451'},
#  {'member_name': 'Biggert, Judy (Republican - Illinois)',
#   'member_id': 'B001232'},
#  {'member_name': 'Biggs, Andy (Republican - Arizona)', 'member_id': 'B001302'},
#  {'member_name': 'Bilbray, Brian P. (Republican - California)',
#   'member_id': 'B000461'},
#  {'member_name': 'Bilbray, James H. (Democratic - Nevada)',
#   'member_id': 'B000462'},
#  {'member_name': 'Bilirakis, Gus M. (Republican - Florida)',
#   'member_id': 'B001257'},
#  {'member_name': 'Bilirakis, Michael (Republican - Florida)',
#   'member_id': 'B000463'},
#  {'member_name': 'Bingaman, Jeff (Democratic - New Mexico)',
#   'member_id': 'B000468'},
#  {'member_name': 'Bingham, Jonathan B. (Democratic - New York)',
#   'member_id': 'B000472'},
#  {'member_name': 'Bishop, Dan (Republican - North Carolina)',
#   'member_id': 'B001311'},
#  {'member_name': 'Bishop, Mike (Republican - Michigan)',
#   'member_id': 'B001293'},
#  {'member_name': 'Bishop, Rob (Republican - Utah)', 'member_id': 'B001250'},
#  {'member_name': 'Bishop, Sanford D., Jr. (Democratic - Georgia)',
#   'member_id': 'B000490'},
#  {'member_name': 'Bishop, Timothy H. (Democratic - New York)',
#   'member_id': 'B001242'},
#  {'member_name': 'Black, Diane (Republican - Tennessee)',
#   'member_id': 'B001273'},
#  {'member_name': 'Blackburn, Ben (Republican - Georgia)',
#   'member_id': 'B000506'},
#  {'member_name': 'Blackburn, Marsha (Republican - Tennessee)',
#   'member_id': 'B001243'},
#  {'member_name': 'Blackwell, Lucien E. (Democratic - Pennsylvania)',
#   'member_id': 'B000517'},
#  {'member_name': 'Blagojevich, Rod R. (Democratic - Illinois)',
#   'member_id': 'B000518'},
#  {'member_name': 'Blanchard, James (Democratic - Michigan)',
#   'member_id': 'B000538'},
#  {'member_name': 'Blatnik, John Anton (Democratic - Minnesota)',
#   'member_id': 'B000550'},
#  {'member_name': 'Blaz, Ben G. (Republican - Guam)', 'member_id': 'B000551'},
#  {'member_name': 'Bliley, Tom (Republican - Virginia)',
#   'member_id': 'B000556'},
#  {'member_name': 'Blouin, Michael (Democratic - Iowa)',
#   'member_id': 'B000567'},
#  {'member_name': 'Blum, Rod (Republican - Iowa)', 'member_id': 'B001294'},
#  {'member_name': 'Blumenauer, Earl (Democratic - Oregon)',
#   'member_id': 'B000574'},
#  {'member_name': 'Blumenthal, Richard (Democratic - Connecticut)',
#   'member_id': 'B001277'},
#  {'member_name': 'Blunt Rochester, Lisa (Democratic - Delaware)',
#   'member_id': 'B001303'},
#  {'member_name': 'Blunt, Roy (Republican - Missouri)', 'member_id': 'B000575'},
#  {'member_name': 'Blute, Peter I. (Republican - Massachusetts)',
#   'member_id': 'B000576'},
#  {'member_name': 'Boccieri, John A. (Democratic - Ohio)',
#   'member_id': 'B001263'},
#  {'member_name': 'Boebert, Lauren (Republican - Colorado)',
#   'member_id': 'B000825'},
#  {'member_name': 'Boehlert, Sherwood (Republican - New York)',
#   'member_id': 'B000586'},
#  {'member_name': 'Boehner, John A. (Republican - Ohio)',
#   'member_id': 'B000589'},
#  {'member_name': 'Boggs, Corinne C. (Lindy) (Democratic - Louisiana)',
#   'member_id': 'B000592'},
#  {'member_name': 'Boland, Edward P. (Democratic - Massachusetts)',
#   'member_id': 'B000600'},
#  {'member_name': 'Bolling, Richard (Democratic - Missouri)',
#   'member_id': 'B000605'},
#  {'member_name': 'Bonamici, Suzanne (Democratic - Oregon)',
#   'member_id': 'B001278'},
#  {'member_name': 'Bond, Christopher S. (Republican - Missouri)',
#   'member_id': 'B000611'},
#  {'member_name': 'Boner, William H. (Democratic - Tennessee)',
#   'member_id': 'B000615'},
#  {'member_name': 'Bonilla, Henry (Republican - Texas)',
#   'member_id': 'B000617'},
#  {'member_name': 'Bonior, David E. (Democratic - Michigan)',
#   'member_id': 'B000619'},
#  {'member_name': 'Bonker, Don (Democratic - Washington)',
#   'member_id': 'B000620'},
#  {'member_name': 'Bonner, Jo (Republican - Alabama)', 'member_id': 'B001244'},
#  {'member_name': 'Bono Mack, Mary (Republican - California)',
#   'member_id': 'B001228'},
#  {'member_name': 'Bono, Sonny (Republican - California)',
#   'member_id': 'B000622'},
#  {'member_name': 'Booker, Cory A. (Democratic - New Jersey)',
#   'member_id': 'B001288'},
#  {'member_name': 'Boozman, John (Republican - Arkansas)',
#   'member_id': 'B001236'},
#  {'member_name': 'Bordallo, Madeleine Z. (Democratic - Guam)',
#   'member_id': 'B001245'},
#  {'member_name': 'Boren, Dan (Democratic - Oklahoma)', 'member_id': 'B001254'},
#  {'member_name': 'Boren, David L. (Democratic - Oklahoma)',
#   'member_id': 'B000639'},
#  {'member_name': 'Borski, Robert A. (Democratic - Pennsylvania)',
#   'member_id': 'B000644'},
#  {'member_name': 'Boschwitz, Rudy (Republican - Minnesota)',
#   'member_id': 'B000647'},
#  {'member_name': 'Bosco, Douglas H. (Democratic - California)',
#   'member_id': 'B000648'},
#  {'member_name': 'Bost, Mike (Republican - Illinois)', 'member_id': 'B001295'},
#  {'member_name': 'Boswell, Leonard L. (Democratic - Iowa)',
#   'member_id': 'B000652'},
#  {'member_name': 'Boucher, Rick (Democratic - Virginia)',
#   'member_id': 'B000657'},
#  {'member_name': 'Boulter, Beau (Republican - Texas)', 'member_id': 'B000666'},
#  {'member_name': 'Bourdeaux, Carolyn (Democratic - Georgia)',
#   'member_id': 'B001312'},
#  {'member_name': 'Boustany, Charles W., Jr. (Republican - Louisiana)',
#   'member_id': 'B001255'},
#  {'member_name': 'Bowen, David R. (Democratic - Mississippi)',
#   'member_id': 'B000682'},
#  {'member_name': 'Bowman, Jamaal (Democratic - New York)',
#   'member_id': 'B001223'},
#  {'member_name': 'Boxer, Barbara (Democratic - California)',
#   'member_id': 'B000711'},
#  {'member_name': 'Boyd, Allen (Democratic - Florida)', 'member_id': 'B000716'},
#  {'member_name': 'Boyda, Nancy E. (Democratic - Kansas)',
#   'member_id': 'B001258'},
#  {'member_name': 'Boyle, Brendan F. (Democratic - Pennsylvania)',
#   'member_id': 'B001296'},
#  {'member_name': 'Brademas, John (Democratic - Indiana)',
#   'member_id': 'B000736'},
#  {'member_name': 'Bradley, Bill (Democratic - New Jersey)',
#   'member_id': 'B001225'},
#  {'member_name': 'Bradley, Jeb (Republican - New Hampshire)',
#   'member_id': 'B001246'},
#  {'member_name': 'Brady, Kevin (Republican - Texas)', 'member_id': 'B000755'},
#  {'member_name': 'Brady, Nicholas (Republican - New Jersey)',
#   'member_id': 'B000756'},
#  {'member_name': 'Brady, Robert A. (Democratic - Pennsylvania)',
#   'member_id': 'B001227'},
#  {'member_name': 'Braley, Bruce L. (Democratic - Iowa)',
#   'member_id': 'B001259'},
#  {'member_name': 'Brasco, Frank (Democratic - New York)',
#   'member_id': 'B000771'},
#  {'member_name': 'Brat, Dave (Republican - Virginia)', 'member_id': 'B001290'},
#  {'member_name': 'Braun, Mike (Republican - Indiana)', 'member_id': 'B001310'},
#  {'member_name': 'Bray, William G. (Republican - Indiana)',
#   'member_id': 'B000778'},
#  {'member_name': 'Breaux, John B. (Democratic - Louisiana)',
#   'member_id': 'B000780'},
#  {'member_name': 'Breckinridge, John B. (Democratic - Kentucky)',
#   'member_id': 'B000788'},
#  {'member_name': 'Brennan, Joseph E. (Democratic - Maine)',
#   'member_id': 'B000798'},
#  {'member_name': 'Brewster, Bill K. (Democratic - Oklahoma)',
#   'member_id': 'B000817'},
#  {'member_name': 'Bridenstine, Jim (Republican - Oklahoma)',
#   'member_id': 'B001283'},
#  {'member_name': 'Bright, Bobby (Democratic - Alabama)',
#   'member_id': 'B001264'},
#  {'member_name': 'Brindisi, Anthony (Democratic - New York)',
#   'member_id': 'B001308'},
#  {'member_name': 'Brinkley, Jack (Democratic - Georgia)',
#   'member_id': 'B000839'},
#  {'member_name': 'Britt, Robin (Democratic - North Carolina)',
#   'member_id': 'B000845'},
#  {'member_name': 'Brock, Bill (Republican - Tennessee)',
#   'member_id': 'B000851'},
#  {'member_name': 'Brodhead, William (Democratic - Michigan)',
#   'member_id': 'B000862'},
#  {'member_name': 'Brooke, Edward W. (Republican - Massachusetts)',
#   'member_id': 'B000871'},
#  {'member_name': 'Brooks, Jack B. (Democratic - Texas)',
#   'member_id': 'B000880'},
#  {'member_name': 'Brooks, Mo (Republican - Alabama)', 'member_id': 'B001274'},
#  {'member_name': 'Brooks, Susan W. (Republican - Indiana)',
#   'member_id': 'B001284'},
#  {'member_name': 'Broomfield, William S. (Republican - Michigan)',
#   'member_id': 'B000890'},
#  {'member_name': 'Brotzman, Donald G. (Republican - Colorado)',
#   'member_id': 'B000893'},
#  {'member_name': 'Broun, Paul C. (Republican - Georgia)',
#   'member_id': 'B001262'},
#  {'member_name': 'Browder, Glen (Democratic - Alabama)',
#   'member_id': 'B000897'},
#  {'member_name': 'Brown, Anthony G. (Democratic - Maryland)',
#   'member_id': 'B001304'},
#  {'member_name': 'Brown, Clarence, Jr. (Republican - Ohio)',
#   'member_id': 'B000910'},
#  {'member_name': 'Brown, Corrine (Democratic - Florida)',
#   'member_id': 'B000911'},
#  {'member_name': 'Brown, Garry E. (Republican - Michigan)',
#   'member_id': 'B000917'},
#  {'member_name': 'Brown, George E., Jr. (Democratic - California)',
#   'member_id': 'B000918'},
#  {'member_name': 'Brown, Hank (Republican - Colorado)',
#   'member_id': 'B000919'},
#  {'member_name': 'Brown, Henry E., Jr. (Republican - South Carolina)',
#   'member_id': 'B001235'},
#  {'member_name': 'Brown, Scott P. (Republican - Massachusetts)',
#   'member_id': 'B001268'},
#  {'member_name': 'Brown, Sherrod (Democratic - Ohio)', 'member_id': 'B000944'},
#  {'member_name': 'Brown-Waite, Ginny (Republican - Florida)',
#   'member_id': 'B001247'},
#  {'member_name': 'Brownback, Sam (Republican - Kansas)',
#   'member_id': 'B000953'},
#  {'member_name': 'Brownley, Julia (Democratic - California)',
#   'member_id': 'B001285'},
#  {'member_name': 'Broyhill, James T. (Republican - North Carolina)',
#   'member_id': 'B000966'},
#  {'member_name': 'Broyhill, Joel T. (Republican - Virginia)',
#   'member_id': 'B000967'},
#  {'member_name': 'Bruce, Terry L. (Democratic - Illinois)',
#   'member_id': 'B000971'},
#  {'member_name': 'Bryan, Richard H. (Democratic - Nevada)',
#   'member_id': 'B000993'},
#  {'member_name': 'Bryant, Ed (Republican - Tennessee)',
#   'member_id': 'B000996'},
#  {'member_name': 'Bryant, John W. (Democratic - Texas)',
#   'member_id': 'B000997'},
#  {'member_name': 'Buchanan, John (Republican - Alabama)',
#   'member_id': 'B001008'},
#  {'member_name': 'Buchanan, Vern (Republican - Florida)',
#   'member_id': 'B001260'},
#  {'member_name': 'Buck, Ken (Republican - Colorado)', 'member_id': 'B001297'},
#  {'member_name': 'Buckley, James L. (Republican - New York)',
#   'member_id': 'B001026'},
#  {'member_name': 'Bucshon, Larry (Republican - Indiana)',
#   'member_id': 'B001275'},
#  {'member_name': 'Budd, Ted (Republican - North Carolina)',
#   'member_id': 'B001305'},
#  {'member_name': 'Buechner, Jack (Republican - Missouri)',
#   'member_id': 'B001036'},
#  {'member_name': 'Buerkle, Ann Marie (Republican - New York)',
#   'member_id': 'B001276'},
#  {'member_name': 'Bumpers, Dale (Democratic - Arkansas)',
#   'member_id': 'B001057'},
#  {'member_name': 'Bunn, Jim (Republican - Oregon)', 'member_id': 'B001063'},
#  {'member_name': 'Bunning, Jim (Republican - Kentucky)',
#   'member_id': 'B001066'},
#  {'member_name': 'Burchett, Tim (Republican - Tennessee)',
#   'member_id': 'B001309'},
#  {'member_name': 'Burdick, Jocelyn (Democratic - North Dakota)',
#   'member_id': 'B001076'},
#  {'member_name': 'Burdick, Quentin N. (Democratic - North Dakota)',
#   'member_id': 'B001077'},
#  {'member_name': 'Burgener, Clair W. (Republican - California)',
#   'member_id': 'B001080'},
#  {'member_name': 'Burgess, Michael C. (Republican - Texas)',
#   'member_id': 'B001248'},
#  {'member_name': 'Burke, J. Herbert (Republican - Florida)',
#   'member_id': 'B001091'},
#  {'member_name': 'Burke, James A. (Democratic - Massachusetts)',
#   'member_id': 'B001092'},
#  {'member_name': 'Burke, Yvonne B. (Democratic - California)',
#   'member_id': 'B001102'},
#  {'member_name': 'Burleson, Omar (Democratic - Texas)',
#   'member_id': 'B001111'},
#  {'member_name': 'Burlison, Bill D. (Democratic - Missouri)',
#   'member_id': 'B001113'},
#  {'member_name': 'Burns, Conrad R. (Republican - Montana)',
#   'member_id': 'B001126'},
#  {'member_name': 'Burns, Max (Republican - Georgia)', 'member_id': 'B001249'},
#  {'member_name': 'Burr, Richard (Republican - North Carolina)',
#   'member_id': 'B001135'},
#  {'member_name': 'Burris, Roland (Democratic - Illinois)',
#   'member_id': 'B001266'},
#  {'member_name': 'Burton, Dan (Republican - Indiana)', 'member_id': 'B001149'},
#  {'member_name': 'Burton, John (Democratic - California)',
#   'member_id': 'B001153'},
#  {'member_name': 'Burton, Phillip (Democratic - California)',
#   'member_id': 'B001156'},
#  {'member_name': 'Burton, Sala (Democratic - California)',
#   'member_id': 'B001158'},
#  {'member_name': 'Bush, Cori (Democratic - Missouri)', 'member_id': 'B001224'},
#  {'member_name': 'Bustamante, Albert G. (Democratic - Texas)',
#   'member_id': 'B001172'},
#  {'member_name': 'Bustos, Cheri (Democratic - Illinois)',
#   'member_id': 'B001286'},
#  {'member_name': 'Butler, M. Caldwell (Republican - Virginia)',
#   'member_id': 'B001182'},
#  {'member_name': 'Butterfield, G. K. (Democratic - North Carolina)',
#   'member_id': 'B001251'},
#  {'member_name': 'Buyer, Steve (Republican - Indiana)',
#   'member_id': 'B001203'},
#  {'member_name': 'Byrd, Harry F., Jr. (Independent - Virginia)',
#   'member_id': 'B001209'},
#  {'member_name': 'Byrd, Robert C. (Democratic - West Virginia)',
#   'member_id': 'B001210'},
#  {'member_name': 'Byrne, Bradley (Republican - Alabama)',
#   'member_id': 'B001289'},
#  {'member_name': 'Byrne, Leslie L. (Democratic - Virginia)',
#   'member_id': 'B001213'},
#  {'member_name': 'Byron, Beverly B. (Democratic - Maryland)',
#   'member_id': 'B001220'},
#  {'member_name': 'Byron, Goodloe E. (Democratic - Maryland)',
#   'member_id': 'B001221'},
#  {'member_name': 'Callahan, Sonny (Republican - Alabama)',
#   'member_id': 'C000052'},
#  {'member_name': 'Calvert, Ken (Republican - California)',
#   'member_id': 'C000059'},
#  {'member_name': 'Cammack, Kat (Republican - Florida)',
#   'member_id': 'C001039'},
#  {'member_name': 'Camp, Dave (Republican - Michigan)', 'member_id': 'C000071'},
#  {'member_name': 'Camp, John N. Happy (Republican - Oklahoma)',
#   'member_id': 'C000073'},
#  {'member_name': 'Campbell, Ben Nighthorse (Republican - Colorado)',
#   'member_id': 'C000077'},
#  {'member_name': 'Campbell, Carroll A., Jr. (Republican - South Carolina)',
#   'member_id': 'C000079'},
#  {'member_name': 'Campbell, John (Republican - California)',
#   'member_id': 'C001064'},
#  {'member_name': 'Campbell, Tom (Republican - California)',
#   'member_id': 'C000100'},
#  {'member_name': 'Canady, Charles T. (Republican - Florida)',
#   'member_id': 'C000107'},
#  {'member_name': 'Cannon, Chris (Republican - Utah)', 'member_id': 'C000116'},
#  {'member_name': 'Cannon, Howard W. (Democratic - Nevada)',
#   'member_id': 'C000120'},
#  {'member_name': 'Canseco, Francisco "Quico" (Republican - Texas)',
#   'member_id': 'C001082'},
#  {'member_name': 'Cantor, Eric (Republican - Virginia)',
#   'member_id': 'C001046'},
#  {'member_name': 'Cantwell, Maria (Democratic - Washington)',
#   'member_id': 'C000127'},
#  {'member_name': 'Cao, Anh "Joseph" (Republican - Louisiana)',
#   'member_id': 'C001079'},
#  {'member_name': 'Capito, Shelley Moore (Republican - West Virginia)',
#   'member_id': 'C001047'},
#  {'member_name': 'Capps, Lois (Democratic - California)',
#   'member_id': 'C001036'},
#  {'member_name': 'Capps, Walter (Democratic - California)',
#   'member_id': 'C000134'},
#  {'member_name': 'Capuano, Michael E. (Democratic - Massachusetts)',
#   'member_id': 'C001037'},
#  {'member_name': 'Caputo, Bruce F. (Republican - New York)',
#   'member_id': 'C000137'},
#  {'member_name': 'Carbajal, Salud O. (Democratic - California)',
#   'member_id': 'C001112'},
#  {'member_name': 'Cardenas, Tony (Democratic - California)',
#   'member_id': 'C001097'},
#  {'member_name': 'Cardin, Benjamin L. (Democratic - Maryland)',
#   'member_id': 'C000141'},
#  {'member_name': 'Cardoza, Dennis A. (Democratic - California)',
#   'member_id': 'C001050'},
#  {'member_name': 'Carey, Hugh L. (Democratic - New York)',
#   'member_id': 'C000143'},
#  {'member_name': 'Carl, Jerry L. (Republican - Alabama)',
#   'member_id': 'C001054'},
#  {'member_name': 'Carman, Gregory W. (Republican - New York)',
#   'member_id': 'C000158'},
#  {'member_name': 'Carnahan, Jean (Democratic - Missouri)',
#   'member_id': 'C001043'},
#  {'member_name': 'Carnahan, Russ (Democratic - Missouri)',
#   'member_id': 'C001060'},
#  {'member_name': 'Carney, Charles J. (Democratic - Ohio)',
#   'member_id': 'C000164'},
#  {'member_name': 'Carney, Christopher P. (Democratic - Pennsylvania)',
#   'member_id': 'C001065'},
#  {'member_name': 'Carney, John C., Jr. (Democratic - Delaware)',
#   'member_id': 'C001083'},
#  {'member_name': 'Carney, William (Republican - New York)',
#   'member_id': 'C000165'},
#  {'member_name': 'Carper, Thomas R. (Democratic - Delaware)',
#   'member_id': 'C000174'},
#  {'member_name': 'Carr, Bob (Democratic - Michigan)', 'member_id': 'C000178'},
#  {'member_name': 'Carson, Andre (Democratic - Indiana)',
#   'member_id': 'C001072'},
#  {'member_name': 'Carson, Brad (Democratic - Oklahoma)',
#   'member_id': 'C001044'},
#  {'member_name': 'Carson, Julia (Democratic - Indiana)',
#   'member_id': 'C000191'},
#  {'member_name': 'Carter, Earl L. "Buddy" (Republican - Georgia)',
#   'member_id': 'C001103'},
#  {'member_name': 'Carter, John R. (Republican - Texas)',
#   'member_id': 'C001051'},
#  {'member_name': 'Carter, Tim Lee (Republican - Kentucky)',
#   'member_id': 'C000201'},
#  {'member_name': 'Cartwright, Matt (Democratic - Pennsylvania)',
#   'member_id': 'C001090'},
#  {'member_name': 'Case, Clifford P. (Republican - New Jersey)',
#   'member_id': 'C000220'},
#  {'member_name': 'Case, Ed (Democratic - Hawaii)', 'member_id': 'C001055'},
#  {'member_name': 'Casey, Bob (Democratic - Texas)', 'member_id': 'C000228'},
#  {'member_name': 'Casey, Robert P., Jr. (Democratic - Pennsylvania)',
#   'member_id': 'C001070'},
#  {'member_name': 'Cassidy, Bill (Republican - Louisiana)',
#   'member_id': 'C001075'},
#  {'member_name': 'Casten, Sean (Democratic - Illinois)',
#   'member_id': 'C001117'},
#  {'member_name': 'Castle, Michael N. (Republican - Delaware)',
#   'member_id': 'C000243'},
#  {'member_name': 'Castor, Kathy (Democratic - Florida)',
#   'member_id': 'C001066'},
#  {'member_name': 'Castro, Joaquin (Democratic - Texas)',
#   'member_id': 'C001091'},
#  {'member_name': 'Cavanaugh, John J. (Democratic - Nebraska)',
#   'member_id': 'C000261'},
#  {'member_name': 'Cawthorn, Madison (Republican - North Carolina)',
#   'member_id': 'C001104'},
#  {'member_name': 'Cazayoux, Donald J., Jr. (Democratic - Louisiana)',
#   'member_id': 'C001073'},
#  {'member_name': 'Cederberg, Elford A. (Republican - Michigan)',
#   'member_id': 'C000263'},
#  {'member_name': 'Chabot, Steve (Republican - Ohio)', 'member_id': 'C000266'},
#  {'member_name': 'Chafee, John H. (Republican - Rhode Island)',
#   'member_id': 'C000269'},
#  {'member_name': 'Chafee, Lincoln (Republican - Rhode Island)',
#   'member_id': 'C001040'},
#  {'member_name': 'Chaffetz, Jason (Republican - Utah)',
#   'member_id': 'C001076'},
#  {'member_name': 'Chamberlain, Charles E. (Republican - Michigan)',
#   'member_id': 'C000275'},
#  {'member_name': 'Chambliss, Saxby (Republican - Georgia)',
#   'member_id': 'C000286'},
#  {'member_name': 'Chandler, Ben (Democratic - Kentucky)',
#   'member_id': 'C001058'},
#  {'member_name': 'Chandler, Rod D. (Republican - Washington)',
#   'member_id': 'C000293'},
#  {'member_name': 'Chapman, Jim (Democratic - Texas)', 'member_id': 'C000312'},
#  {'member_name': 'Chappell, Bill, Jr. (Democratic - Florida)',
#   'member_id': 'C000321'},
#  {'member_name': 'Chappie, Eugene A. (Republican - California)',
#   'member_id': 'C000322'},
#  {'member_name': 'Cheney, Dick (Republican - Wyoming)',
#   'member_id': 'C000344'},
#  {'member_name': 'Cheney, Liz (Republican - Wyoming)', 'member_id': 'C001109'},
#  {'member_name': 'Chenoweth-Hage, Helen (Republican - Idaho)',
#   'member_id': 'C000345'},
#  {'member_name': 'Chiesa, Jeff (Republican - New Jersey)',
#   'member_id': 'C001100'},
#  {'member_name': 'Childers, Travis (Democratic - Mississippi)',
#   'member_id': 'C001074'},
#  {'member_name': 'Chiles, Lawton (Democratic - Florida)',
#   'member_id': 'C000356'},
#  {'member_name': 'Chisholm, Shirley (Democratic - New York)',
#   'member_id': 'C000371'},
#  {'member_name': 'Chocola, Chris (Republican - Indiana)',
#   'member_id': 'C001052'},
#  {'member_name': 'Christensen, Donna M. (Democratic - Virgin Islands)',
#   'member_id': 'C000380'},
#  {'member_name': 'Christensen, Jon (Republican - Nebraska)',
#   'member_id': 'C000377'},
#  {'member_name': 'Chrysler, Dick (Republican - Michigan)',
#   'member_id': 'C000385'},
#  {'member_name': 'Chu, Judy (Democratic - California)',
#   'member_id': 'C001080'},
#  {'member_name': 'Church, Frank (Democratic - Idaho)', 'member_id': 'C000388'},
#  {'member_name': 'Cicilline, David N. (Democratic - Rhode Island)',
#   'member_id': 'C001084'},
#  {'member_name': 'Cisneros, Gilbert Ray, Jr. (Democratic - California)',
#   'member_id': 'C001123'},
#  {'member_name': 'Clancy, Donald D. (Republican - Ohio)',
#   'member_id': 'C000409'},
#  {'member_name': 'Clark, Dick (Democratic - Iowa)', 'member_id': 'C000448'},
#  {'member_name': 'Clark, Frank M. (Democratic - Pennsylvania)',
#   'member_id': 'C000431'},
#  {'member_name': 'Clark, Katherine M. (Democratic - Massachusetts)',
#   'member_id': 'C001101'},
#  {'member_name': 'Clarke, Hansen (Democratic - Michigan)',
#   'member_id': 'C001085'},
#  {'member_name': 'Clarke, James McC. (Democratic - North Carolina)',
#   'member_id': 'C000462'},
#  {'member_name': 'Clarke, Yvette D. (Democratic - New York)',
#   'member_id': 'C001067'},
#  {'member_name': 'Clausen, Don H. (Republican - California)',
#   'member_id': 'C000475'},
#  {'member_name': 'Clawson, Curt (Republican - Florida)',
#   'member_id': 'C001102'},
#  {'member_name': 'Clawson, Del (Republican - California)',
#   'member_id': 'C000476'},
#  {'member_name': 'Clay, William (Bill) (Democratic - Missouri)',
#   'member_id': 'C000488'},
#  {'member_name': 'Clay, Wm. Lacy (Democratic - Missouri)',
#   'member_id': 'C001049'},
#  {'member_name': 'Clayton, Eva M. (Democratic - North Carolina)',
#   'member_id': 'C000494'},
#  {'member_name': 'Cleaver, Emanuel (Democratic - Missouri)',
#   'member_id': 'C001061'},
#  {'member_name': 'Cleland, Max (Democratic - Georgia)',
#   'member_id': 'C001034'},
#  {'member_name': 'Clement, Bob (Democratic - Tennessee)',
#   'member_id': 'C000503'},
#  {'member_name': 'Cleveland, James C. (Republican - New Hampshire)',
#   'member_id': 'C000512'},
#  {'member_name': 'Cline, Ben (Republican - Virginia)', 'member_id': 'C001118'},
#  {'member_name': 'Clinger, William F., Jr. (Republican - Pennsylvania)',
#   'member_id': 'C000523'},
#  {'member_name': 'Clinton, Hillary Rodham (Democratic - New York)',
#   'member_id': 'C001041'},
#  {'member_name': 'Cloud, Michael (Republican - Texas)',
#   'member_id': 'C001115'},
#  {'member_name': 'Clyburn, James E. (Democratic - South Carolina)',
#   'member_id': 'C000537'},
#  {'member_name': 'Clyde, Andrew S. (Republican - Georgia)',
#   'member_id': 'C001116'},
#  {'member_name': 'Coats, Daniel (Republican - Indiana)',
#   'member_id': 'C000542'},
#  {'member_name': 'Cobey, William W. (Republican - North Carolina)',
#   'member_id': 'C000555'},
#  {'member_name': 'Coble, Howard (Republican - North Carolina)',
#   'member_id': 'C000556'},
#  {'member_name': 'Coburn, Tom (Republican - Oklahoma)',
#   'member_id': 'C000560'},
#  {'member_name': 'Cochran, Thad (Republican - Mississippi)',
#   'member_id': 'C000567'},
#  {'member_name': 'Coelho, Anthony Lee (Democratic - California)',
#   'member_id': 'C000581'},
#  {'member_name': 'Coffman, Mike (Republican - Colorado)',
#   'member_id': 'C001077'},
#  {'member_name': 'Cohen, Steve (Democratic - Tennessee)',
#   'member_id': 'C001068'},
#  {'member_name': 'Cohen, William S. (Republican - Maine)',
#   'member_id': 'C000598'},
#  {'member_name': 'Cole, Tom (Republican - Oklahoma)', 'member_id': 'C001053'},
#  {'member_name': 'Coleman, E. Thomas (Republican - Missouri)',
#   'member_id': 'C000618'},
#  {'member_name': 'Coleman, Norm (Republican - Minnesota)',
#   'member_id': 'C001057'},
#  {'member_name': 'Coleman, Ronald D. (Democratic - Texas)',
#   'member_id': 'C000621'},
#  {'member_name': 'Collier, Harold R. (Republican - Illinois)',
#   'member_id': 'C000629'},
#  {'member_name': 'Collins, Barbara-Rose (Democratic - Michigan)',
#   'member_id': 'C000633'},
#  {'member_name': 'Collins, Cardiss (Democratic - Illinois)',
#   'member_id': 'C000634'},
#  {'member_name': 'Collins, Chris (Republican - New York)',
#   'member_id': 'C001092'},
#  {'member_name': 'Collins, Doug (Republican - Georgia)',
#   'member_id': 'C001093'},
#  {'member_name': 'Collins, James M. (Republican - Texas)',
#   'member_id': 'C000638'},
#  {'member_name': 'Collins, Mac (Republican - Georgia)',
#   'member_id': 'C000640'},
#  {'member_name': 'Collins, Susan M. (Republican - Maine)',
#   'member_id': 'C001035'},
#  {'member_name': 'Colorado, Antonio (Democratic - Puerto Rico)',
#   'member_id': 'C000646'},
#  {'member_name': 'Combest, Larry (Republican - Texas)',
#   'member_id': 'C000653'},
#  {'member_name': 'Comer, James (Republican - Kentucky)',
#   'member_id': 'C001108'},
#  {'member_name': 'Comstock, Barbara (Republican - Virginia)',
#   'member_id': 'C001105'},
#  {'member_name': 'Conable, Barber B., Jr. (Republican - New York)',
#   'member_id': 'C000666'},
#  {'member_name': 'Conaway, K. Michael (Republican - Texas)',
#   'member_id': 'C001062'},
#  {'member_name': 'Condit, Gary A. (Democratic - California)',
#   'member_id': 'C000670'},
#  {'member_name': 'Conlan, John B. (Republican - Arizona)',
#   'member_id': 'C000682'},
#  {'member_name': 'Connolly, Gerald E. (Democratic - Virginia)',
#   'member_id': 'C001078'},
#  {'member_name': 'Conrad, Kent (Democratic - North Dakota)',
#   'member_id': 'C000705'},
#  {'member_name': 'Conte, Silvio O. (Republican - Massachusetts)',
#   'member_id': 'C000709'},
#  {'member_name': 'Conyers, John, Jr. (Democratic - Michigan)',
#   'member_id': 'C000714'},
#  {'member_name': 'Cook, Marlow W. (Republican - Kentucky)',
#   'member_id': 'C000721'},
#  {'member_name': 'Cook, Merrill (Republican - Utah)', 'member_id': 'C000722'},
#  {'member_name': 'Cook, Paul (Republican - California)',
#   'member_id': 'C001094'},
#  {'member_name': 'Cooksey, John (Republican - Louisiana)',
#   'member_id': 'C000735'},
#  {'member_name': 'Cooley, Wes (Republican - Oregon)', 'member_id': 'C000737'},
#  {'member_name': 'Coons, Christopher A. (Democratic - Delaware)',
#   'member_id': 'C001088'},
#  {'member_name': 'Cooper, Jim (Democratic - Tennessee)',
#   'member_id': 'C000754'},
#  {'member_name': 'Coppersmith, Sam (Democratic - Arizona)',
#   'member_id': 'C000767'},
#  {'member_name': 'Corcoran, Tom (Republican - Illinois)',
#   'member_id': 'C000773'},
#  {'member_name': 'Corker, Bob (Republican - Tennessee)',
#   'member_id': 'C001071'},
#  {'member_name': 'Corman, James C. (Democratic - California)',
#   'member_id': 'C000780'},
#  {'member_name': 'Cornell, Robert J. (Democratic - Wisconsin)',
#   'member_id': 'C000782'},
#  {'member_name': 'Cornwell, David L. (Democratic - Indiana)',
#   'member_id': 'C000787'},
#  {'member_name': 'Cornyn, John (Republican - Texas)', 'member_id': 'C001056'},
#  {'member_name': 'Corrada, Baltasar (Independent - Puerto Rico)',
#   'member_id': 'C000788'},
#  {'member_name': 'Correa, J. Luis (Democratic - California)',
#   'member_id': 'C001110'},
#  {'member_name': 'Cortez Masto, Catherine (Democratic - Nevada)',
#   'member_id': 'C001113'},
#  {'member_name': 'Corzine, Jon S. (Democratic - New Jersey)',
#   'member_id': 'C001042'},
#  {'member_name': 'Costa, Jim (Democratic - California)',
#   'member_id': 'C001059'},
#  {'member_name': 'Costello, Jerry F. (Democratic - Illinois)',
#   'member_id': 'C000794'},
#  {'member_name': 'Costello, Ryan A. (Republican - Pennsylvania)',
#   'member_id': 'C001106'},
#  {'member_name': 'Cotter, William R. (Democratic - Connecticut)',
#   'member_id': 'C000799'},
#  {'member_name': 'Cotton, Norris (Republican - New Hampshire)',
#   'member_id': 'C000802'},
#  {'member_name': 'Cotton, Tom (Republican - Arkansas)',
#   'member_id': 'C001095'},
#  {'member_name': 'Coughlin, Lawrence (Republican - Pennsylvania)',
#   'member_id': 'C000807'},
#  {'member_name': 'Courter, Jim (Republican - New Jersey)',
#   'member_id': 'C000809'},
#  {'member_name': 'Courtney, Joe (Democratic - Connecticut)',
#   'member_id': 'C001069'},
#  {'member_name': 'Coverdell, Paul (Republican - Georgia)',
#   'member_id': 'C000813'},
#  {'member_name': 'Cowan, William M. (Democratic - Massachusetts)',
#   'member_id': 'C001099'},
#  {'member_name': 'Cox, Christopher (Republican - California)',
#   'member_id': 'C000830'},
#  {'member_name': 'Cox, John W., Jr. (Democratic - Illinois)',
#   'member_id': 'C000836'},
#  {'member_name': 'Cox, TJ (Democratic - California)', 'member_id': 'C001124'},
#  {'member_name': 'Coyne, James K. (Republican - Pennsylvania)',
#   'member_id': 'C000845'},
#  {'member_name': 'Coyne, William J. (Democratic - Pennsylvania)',
#   'member_id': 'C000846'},
#  {'member_name': 'Craig, Angie (Democratic - Minnesota)',
#   'member_id': 'C001119'},
#  {'member_name': 'Craig, Larry E. (Republican - Idaho)',
#   'member_id': 'C000858'},
#  {'member_name': 'Cramer, Kevin (Republican - North Dakota)',
#   'member_id': 'C001096'},
#  {'member_name': 'Cramer, Robert E. (Bud), Jr. (Democratic - Alabama)',
#   'member_id': 'C000868'},
#  {'member_name': 'Crane, Daniel B. (Republican - Illinois)',
#   'member_id': 'C000871'},
#  {'member_name': 'Crane, Philip M. (Republican - Illinois)',
#   'member_id': 'C000873'},
#  {'member_name': 'Cranston, Alan (Democratic - California)',
#   'member_id': 'C000877'},
#  {'member_name': 'Crapo, Mike (Republican - Idaho)', 'member_id': 'C000880'},
#  {'member_name': 'Cravaack, Chip (Republican - Minnesota)',
#   'member_id': 'C001086'},
#  {'member_name': 'Crawford, Eric A. "Rick" (Republican - Arkansas)',
#   'member_id': 'C001087'},
#  {'member_name': 'Cremeans, Frank A. (Republican - Ohio)',
#   'member_id': 'C000903'},
#  {'member_name': 'Crenshaw, Ander (Republican - Florida)',
#   'member_id': 'C001045'},
#  {'member_name': 'Crenshaw, Dan (Republican - Texas)', 'member_id': 'C001120'},
#  {'member_name': 'Crist, Charlie (Democratic - Florida)',
#   'member_id': 'C001111'},
#  {'member_name': 'Critz, Mark S. (Democratic - Pennsylvania)',
#   'member_id': 'C001081'},
#  {'member_name': 'Crockett, George W., Jr. (Democratic - Michigan)',
#   'member_id': 'C000919'},
#  {'member_name': 'Cronin, Paul W. (Republican - Massachusetts)',
#   'member_id': 'C000925'},
#  {'member_name': 'Crow, Jason (Democratic - Colorado)',
#   'member_id': 'C001121'},
#  {'member_name': 'Crowley, Joseph (Democratic - New York)',
#   'member_id': 'C001038'},
#  {'member_name': 'Cruz, Ted (Republican - Texas)', 'member_id': 'C001098'},
#  {'member_name': 'Cubin, Barbara (Republican - Wyoming)',
#   'member_id': 'C000962'},
#  {'member_name': 'Cuellar, Henry (Democratic - Texas)',
#   'member_id': 'C001063'},
#  {'member_name': 'Culberson, John Abney (Republican - Texas)',
#   'member_id': 'C001048'},
#  {'member_name': 'Culver, John C. (Democratic - Iowa)',
#   'member_id': 'C000979'},
#  {'member_name': 'Cummings, Elijah E. (Democratic - Maryland)',
#   'member_id': 'C000984'},
#  {'member_name': 'Cunningham, Joe (Democratic - South Carolina)',
#   'member_id': 'C001122'},
#  {'member_name': 'Cunningham, John E. (Jack) (Republican - Washington)',
#   'member_id': 'C000992'},
#  {'member_name': 'Cunningham, Randy (Duke) (Republican - California)',
#   'member_id': 'C000994'},
#  {'member_name': 'Curbelo, Carlos (Republican - Florida)',
#   'member_id': 'C001107'},
#  {'member_name': 'Curson, David Alan (Democratic - Michigan)',
#   'member_id': 'C001089'},
#  {'member_name': 'Curtis, Carl T. (Republican - Nebraska)',
#   'member_id': 'C001006'},
#  {'member_name': 'Curtis, John R. (Republican - Utah)',
#   'member_id': 'C001114'},
#  {'member_name': "D'Amato, Alfonse (Republican - New York)",
#   'member_id': 'D000018'},
#  {'member_name': "D'Amours, Norman E. (Democratic - New Hampshire)",
#   'member_id': 'D000017'},
#  {'member_name': 'Dahlkemper, Kathleen A. (Democratic - Pennsylvania)',
#   'member_id': 'D000608'},
#  {'member_name': 'Daines, Steve (Republican - Montana)',
#   'member_id': 'D000618'},
#  {'member_name': 'Danforth, John C. (Republican - Missouri)',
#   'member_id': 'D000030'},
#  {'member_name': 'Daniel, Robert W., Jr. (Republican - Virginia)',
#   'member_id': 'D000037'},
#  {'member_name': 'Daniel, W. C. (Dan) (Democratic - Virginia)',
#   'member_id': 'D000038'},
#  {'member_name': 'Daniels, Dominick V. (Democratic - New Jersey)',
#   'member_id': 'D000041'},
#  {'member_name': 'Danielson, George E. (Democratic - California)',
#   'member_id': 'D000043'},
#  {'member_name': 'Dannemeyer, William E. (Republican - California)',
#   'member_id': 'D000044'},
#  {'member_name': 'Danner, Pat (Democratic - Missouri)',
#   'member_id': 'D000046'},
#  {'member_name': 'Darden, George (Buddy) (Democratic - Georgia)',
#   'member_id': 'D000051'},
#  {'member_name': 'Daschle, Thomas A. (Democratic - South Dakota)',
#   'member_id': 'D000064'},
#  {'member_name': 'Daub, Hal (Republican - Nebraska)', 'member_id': 'D000065'},
#  {'member_name': 'Davids, Sharice (Democratic - Kansas)',
#   'member_id': 'D000629'},
#  {'member_name': 'Davidson, Warren (Republican - Ohio)',
#   'member_id': 'D000626'},
#  {'member_name': 'Davis, Artur (Democratic - Alabama)',
#   'member_id': 'D000602'},
#  {'member_name': 'Davis, Danny K. (Democratic - Illinois)',
#   'member_id': 'D000096'},
#  {'member_name': 'Davis, David (Republican - Tennessee)',
#   'member_id': 'D000606'},
#  {'member_name': 'Davis, Geoff (Republican - Kentucky)',
#   'member_id': 'D000603'},
#  {'member_name': 'Davis, Glenn R. (Republican - Wisconsin)',
#   'member_id': 'D000102'},
#  {'member_name': 'Davis, Jack (Republican - Illinois)',
#   'member_id': 'D000106'},
#  {'member_name': 'Davis, Jim (Democratic - Florida)', 'member_id': 'D000114'},
#  {'member_name': 'Davis, Jo Ann (Republican - Virginia)',
#   'member_id': 'D000597'},
#  {'member_name': 'Davis, John W. (Democratic - Georgia)',
#   'member_id': 'D000122'},
#  {'member_name': 'Davis, Lincoln (Democratic - Tennessee)',
#   'member_id': 'D000599'},
# ...
#  {'member_name': 'Garbarino, Andrew R. (Republican - New York)',
#   'member_id': 'G000597'},
#  {'member_name': 'Garcia, Jesus G. "Chuy" (Democratic - Illinois)',
#   'member_id': 'G000586'},
#  {'member_name': 'Garcia, Joe (Democratic - Florida)', 'member_id': 'G000573'},
#  {'member_name': 'Garcia, Mike (Republican - California)',
#   'member_id': 'G000061'},
#  {'member_name': 'Garcia, Robert (Democratic - New York)',
#   'member_id': 'G000047'},
#  {'member_name': 'Garcia, Sylvia R. (Democratic - Texas)',
#   'member_id': 'G000587'},
#  {'member_name': 'Gardner, Cory (Republican - Colorado)',
#   'member_id': 'G000562'},
#  {'member_name': 'Garn, E. J. (Jake) (Republican - Utah)',
#   'member_id': 'G000072'},
#  {'member_name': 'Garrett, Scott (Republican - New Jersey)',
#   'member_id': 'G000548'},
#  {'member_name': 'Garrett, Thomas A., Jr. (Republican - Virginia)',
#   'member_id': 'G000580'},
#  {'member_name': 'Gaydos, Joseph M. (Democratic - Pennsylvania)',
#   'member_id': 'G000105'},
#  {'member_name': 'Gejdenson, Sam (Democratic - Connecticut)',
#   'member_id': 'G000120'},
#  {'member_name': 'Gekas, George W. (Republican - Pennsylvania)',
#   'member_id': 'G000121'},
#  {'member_name': 'Gephardt, Richard A. (Democratic - Missouri)',
#   'member_id': 'G000132'},
#  {'member_name': 'Geren, Pete (Democratic - Texas)', 'member_id': 'G000134'},
#  {'member_name': 'Gerlach, Jim (Republican - Pennsylvania)',
#   'member_id': 'G000549'},
#  {'member_name': 'Gettys, Tom S. (Democratic - South Carolina)',
#   'member_id': 'G000144'},
#  {'member_name': 'Giaimo, Robert N. (Democratic - Connecticut)',
#   'member_id': 'G000151'},
#  {'member_name': 'Gianforte, Greg (Republican - Montana)',
#   'member_id': 'G000584'},
#  {'member_name': 'Gibbons, Jim (Republican - Nevada)', 'member_id': 'G000152'},
#  {'member_name': 'Gibbons, Sam (Democratic - Florida)',
#   'member_id': 'G000153'},
#  {'member_name': 'Gibbs, Bob (Republican - Ohio)', 'member_id': 'G000563'},
#  {'member_name': 'Gibson, Christopher P. (Republican - New York)',
#   'member_id': 'G000564'},
#  {'member_name': 'Giffords, Gabrielle (Democratic - Arizona)',
#   'member_id': 'G000554'},
#  {'member_name': 'Gilchrest, Wayne T. (Republican - Maryland)',
#   'member_id': 'G000180'},
#  {'member_name': 'Gillibrand, Kirsten E. (Democratic - New York)',
#   'member_id': 'G000555'},
#  {'member_name': 'Gillmor, Paul E. (Republican - Ohio)',
#   'member_id': 'G000210'},
#  {'member_name': 'Gilman, Benjamin A. (Republican - New York)',
#   'member_id': 'G000212'},
#  {'member_name': 'Gimenez, Carlos A. (Republican - Florida)',
#   'member_id': 'G000593'},
#  {'member_name': 'Gingrey, Phil (Republican - Georgia)',
#   'member_id': 'G000550'},
#  {'member_name': 'Gingrich, Newt (Republican - Georgia)',
#   'member_id': 'G000225'},
#  {'member_name': 'Ginn, Bo (Democratic - Georgia)', 'member_id': 'G000226'},
#  {'member_name': 'Glenn, John H., Jr. (Democratic - Ohio)',
#   'member_id': 'G000236'},
#  {'member_name': 'Glickman, Dan (Democratic - Kansas)',
#   'member_id': 'G000240'},
#  {'member_name': 'Gohmert, Louie (Republican - Texas)',
#   'member_id': 'G000552'},
#  {'member_name': 'Golden, Jared F. (Democratic - Maine)',
#   'member_id': 'G000592'},
#  {'member_name': 'Goldwater, Barry (Republican - Arizona)',
#   'member_id': 'G000267'},
#  {'member_name': 'Goldwater, Barry, Jr. (Republican - California)',
#   'member_id': 'G000268'},
#  {'member_name': 'Gomez, Jimmy (Democratic - California)',
#   'member_id': 'G000585'},
#  {'member_name': 'Gonzales, Tony (Republican - Texas)',
#   'member_id': 'G000594'},
#  {'member_name': 'Gonzalez, Anthony (Republican - Ohio)',
#   'member_id': 'G000588'},
#  {'member_name': 'Gonzalez, Charles A. (Democratic - Texas)',
#   'member_id': 'G000544'},
#  {'member_name': 'Gonzalez, Henry B. (Democratic - Texas)',
#   'member_id': 'G000272'},
#  {'member_name': 'Gonzalez, Vicente (Democratic - Texas)',
#   'member_id': 'G000581'},
#  {'member_name': 'Gonzalez-Colon, Jenniffer (Republican - Puerto Rico)',
#   'member_id': 'G000582'},
#  {'member_name': 'Good, Bob (Republican - Virginia)', 'member_id': 'G000595'},
#  {'member_name': 'Goode, Virgil H., Jr. (Republican - Virginia)',
#   'member_id': 'G000280'},
#  {'member_name': 'Gooden, Lance (Republican - Texas)', 'member_id': 'G000589'},
#  {'member_name': 'Goodlatte, Bob (Republican - Virginia)',
#   'member_id': 'G000289'},
#  {'member_name': 'Goodling, George A. (Republican - Pennsylvania)',
#   'member_id': 'G000290'},
#  {'member_name': 'Goodling, William F. (Republican - Pennsylvania)',
#   'member_id': 'G000291'},
#  {'member_name': 'Goodwin, Carte Patrick (Democratic - West Virginia)',
#   'member_id': 'G000561'},
#  {'member_name': 'Gordon, Bart (Democratic - Tennessee)',
#   'member_id': 'G000309'},
#  {'member_name': 'Gore, Albert, Jr. (Democratic - Tennessee)',
#   'member_id': 'G000321'},
#  {'member_name': 'Gorton, Slade (Republican - Washington)',
#   'member_id': 'G000333'},
#  {'member_name': 'Gosar, Paul A. (Republican - Arizona)',
#   'member_id': 'G000565'},
#  {'member_name': 'Goss, Porter J. (Republican - Florida)',
#   'member_id': 'G000336'},
#  {'member_name': 'Gottheimer, Josh (Democratic - New Jersey)',
#   'member_id': 'G000583'},
#  {'member_name': 'Gowdy, Trey (Republican - South Carolina)',
#   'member_id': 'G000566'},
#  {'member_name': 'Gradison, Willis D., Jr. (Republican - Ohio)',
#   'member_id': 'G000349'},
#  {'member_name': 'Graham, Bob (Democratic - Florida)', 'member_id': 'G000352'},
#  {'member_name': 'Graham, Gwen (Democratic - Florida)',
#   'member_id': 'G000575'},
#  {'member_name': 'Graham, Lindsey (Republican - South Carolina)',
#   'member_id': 'G000359'},
#  {'member_name': 'Gramm, Phil (Republican - Texas)', 'member_id': 'G000365'},
#  {'member_name': 'Grams, Rod (Republican - Minnesota)',
#   'member_id': 'G000367'},
#  {'member_name': 'Grandy, Fred (Republican - Iowa)', 'member_id': 'G000371'},
#  {'member_name': 'Granger, Kay (Republican - Texas)', 'member_id': 'G000377'},
#  {'member_name': 'Grant, Bill (Republican - Florida)', 'member_id': 'G000382'},
#  {'member_name': 'Grassley, Chuck (Republican - Iowa)',
#   'member_id': 'G000386'},
#  {'member_name': 'Grasso, Ella T. (Democratic - Connecticut)',
#   'member_id': 'G000387'},
#  {'member_name': 'Gravel, Mike (Democratic - Alaska)', 'member_id': 'G000388'},
#  {'member_name': 'Graves, Garret (Republican - Louisiana)',
#   'member_id': 'G000577'},
#  {'member_name': 'Graves, Sam (Republican - Missouri)',
#   'member_id': 'G000546'},
#  {'member_name': 'Graves, Tom (Republican - Georgia)', 'member_id': 'G000560'},
#  {'member_name': 'Gray, Kenneth J. (Democratic - Illinois)',
#   'member_id': 'G000400'},
#  {'member_name': 'Gray, William H., III (Democratic - Pennsylvania)',
#   'member_id': 'G000402'},
#  {'member_name': 'Grayson, Alan (Democratic - Florida)',
#   'member_id': 'G000556'},
#  {'member_name': 'Green, Al (Democratic - Texas)', 'member_id': 'G000553'},
#  {'member_name': 'Green, Edith (Democratic - Oregon)', 'member_id': 'G000407'},
#  {'member_name': 'Green, Gene (Democratic - Texas)', 'member_id': 'G000410'},
#  {'member_name': 'Green, Mark (Republican - Wisconsin)',
#   'member_id': 'G000545'},
#  {'member_name': 'Green, Mark E. (Republican - Tennessee)',
#   'member_id': 'G000590'},
#  {'member_name': 'Green, S. William (Republican - New York)',
#   'member_id': 'G000417'},
#  {'member_name': 'Green, William J. (Democratic - Pennsylvania)',
#   'member_id': 'G000420'},
#  {'member_name': 'Greene, Marjorie Taylor (Republican - Georgia)',
#   'member_id': 'G000596'},
#  {'member_name': 'Greenwood, James C. (Republican - Pennsylvania)',
#   'member_id': 'G000439'},
#  {'member_name': 'Gregg, Judd (Republican - New Hampshire)',
#   'member_id': 'G000445'},
#  {'member_name': 'Griffin, Robert P. (Republican - Michigan)',
#   'member_id': 'G000465'},
#  {'member_name': 'Griffin, Tim (Republican - Arkansas)',
#   'member_id': 'G000567'},
#  {'member_name': 'Griffith, H. Morgan (Republican - Virginia)',
#   'member_id': 'G000568'},
#  {'member_name': 'Griffith, Parker (Republican - Alabama)',
#   'member_id': 'G000557'},
#  {'member_name': 'Griffiths, Martha W. (Democratic - Michigan)',
#   'member_id': 'G000471'},
#  {'member_name': 'Grijalva, Raul M. (Democratic - Arizona)',
#   'member_id': 'G000551'},
#  {'member_name': 'Grimm, Michael G. (Republican - New York)',
#   'member_id': 'G000569'},
#  {'member_name': 'Grisham, Wayne R. (Republican - California)',
#   'member_id': 'G000480'},
#  {'member_name': 'Gross, H. R. (Republican - Iowa)', 'member_id': 'G000495'},
#  {'member_name': 'Grotberg, John E. (Republican - Illinois)',
#   'member_id': 'G000499'},
#  {'member_name': 'Grothman, Glenn (Republican - Wisconsin)',
#   'member_id': 'G000576'},
#  {'member_name': 'Grover, James R., Jr. (Republican - New York)',
#   'member_id': 'G000504'},
#  {'member_name': 'Grucci, Felix J., Jr. (Republican - New York)',
#   'member_id': 'G000547'},
#  {'member_name': 'Guarini, Frank J. (Democratic - New Jersey)',
#   'member_id': 'G000511'},
#  {'member_name': 'Gubser, Charles S. (Republican - California)',
#   'member_id': 'G000512'},
#  {'member_name': 'Gude, Gilbert (Republican - Maryland)',
#   'member_id': 'G000513'},
#  {'member_name': 'Gudger, V. Lamar (Democratic - North Carolina)',
#   'member_id': 'G000515'},
#  {'member_name': 'Guest, Michael (Republican - Mississippi)',
#   'member_id': 'G000591'},
#  {'member_name': 'Guinta, Frank C. (Republican - New Hampshire)',
#   'member_id': 'G000570'},
#  {'member_name': 'Gunderson, Steve (Republican - Wisconsin)',
#   'member_id': 'G000524'},
#  {'member_name': 'Gunter, Bill (Democratic - Florida)',
#   'member_id': 'G000528'},
#  {'member_name': 'Gurney, Edward J. (Republican - Florida)',
#   'member_id': 'G000531'},
#  {'member_name': 'Guthrie, Brett (Republican - Kentucky)',
#   'member_id': 'G000558'},
#  {'member_name': 'Gutierrez, Luis V. (Democratic - Illinois)',
#   'member_id': 'G000535'},
#  {'member_name': 'Gutknecht, Gil (Republican - Minnesota)',
#   'member_id': 'G000536'},
#  {'member_name': 'Guyer, Tennyson (Republican - Ohio)',
#   'member_id': 'G000537'},
#  {'member_name': 'Haaland, Debra A. (Democratic - New Mexico)',
#   'member_id': 'H001080'},
#  {'member_name': 'Hagan, Kay R. (Democratic - North Carolina)',
#   'member_id': 'H001049'},
#  {'member_name': 'Hagedorn, Jim (Republican - Minnesota)',
#   'member_id': 'H001088'},
#  {'member_name': 'Hagedorn, Thomas M. (Republican - Minnesota)',
#   'member_id': 'H000012'},
#  {'member_name': 'Hagel, Chuck (Republican - Nebraska)',
#   'member_id': 'H001028'},
#  {'member_name': 'Hagerty, Bill (Republican - Tennessee)',
#   'member_id': 'H000601'},
#  {'member_name': 'Hahn, Janice (Democratic - California)',
#   'member_id': 'H001063'},
#  {'member_name': 'Haley, James A. (Democratic - Florida)',
#   'member_id': 'H000041'},
#  {'member_name': 'Hall, John J. (Democratic - New York)',
#   'member_id': 'H001039'},
#  {'member_name': 'Hall, Katie (Democratic - Indiana)', 'member_id': 'H000058'},
#  {'member_name': 'Hall, Kwanza (Democratic - Georgia)',
#   'member_id': 'H001092'},
#  {'member_name': 'Hall, Ralph M. (Republican - Texas)',
#   'member_id': 'H000067'},
#  {'member_name': 'Hall, Sam B., Jr. (Democratic - Texas)',
#   'member_id': 'H000070'},
#  {'member_name': 'Hall, Tim L. (Democratic - Illinois)',
#   'member_id': 'H000073'},
#  {'member_name': 'Hall, Tony P. (Democratic - Ohio)', 'member_id': 'H000074'},
#  {'member_name': 'Halvorson, Deborah L. (Democratic - Illinois)',
#   'member_id': 'H001044'},
#  {'member_name': 'Hamburg, Dan (Democratic - California)',
#   'member_id': 'H000096'},
#  {'member_name': 'Hamilton, Lee H. (Democratic - Indiana)',
#   'member_id': 'H000114'},
#  {'member_name': 'Hammerschmidt, John P. (Republican - Arkansas)',
#   'member_id': 'H000124'},
#  {'member_name': 'Hanabusa, Colleen (Democratic - Hawaii)',
#   'member_id': 'H001050'},
#  {'member_name': 'Hance, Kent R. (Democratic - Texas)',
#   'member_id': 'H000144'},
#  {'member_name': 'Hancock, Mel (Republican - Missouri)',
#   'member_id': 'H000151'},
#  {'member_name': 'Handel, Karen C. (Republican - Georgia)',
#   'member_id': 'H001078'},
#  {'member_name': 'Hanley, James M. (Democratic - New York)',
#   'member_id': 'H000158'},
#  {'member_name': 'Hanna, Richard L. (Republican - New York)',
#   'member_id': 'H001051'},
#  {'member_name': 'Hanna, Richard T. (Democratic - California)',
#   'member_id': 'H000164'},
#  {'member_name': 'Hannaford, Mark W. (Democratic - California)',
#   'member_id': 'H000166'},
#  {'member_name': 'Hanrahan, Robert P. (Republican - Illinois)',
#   'member_id': 'H000168'},
#  {'member_name': 'Hansen, Clifford P. (Republican - Wyoming)',
#   'member_id': 'H000170'},
#  {'member_name': 'Hansen, George V. (Republican - Idaho)',
#   'member_id': 'H000171'},
#  {'member_name': 'Hansen, James V. (Republican - Utah)',
#   'member_id': 'H000172'},
#  {'member_name': 'Hansen, Julia Butler (Democratic - Washington)',
#   'member_id': 'H000174'},
#  {'member_name': 'Hansen, Orval (Republican - Idaho)', 'member_id': 'H000175'},
#  {'member_name': 'Harder, Josh (Democratic - California)',
#   'member_id': 'H001090'},
#  {'member_name': 'Hardy, Cresent (Republican - Nevada)',
#   'member_id': 'H001070'},
#  {'member_name': 'Hare, Phil (Democratic - Illinois)', 'member_id': 'H001040'},
#  {'member_name': 'Harkin, Tom (Democratic - Iowa)', 'member_id': 'H000206'},
#  {'member_name': 'Harman, Jane (Democratic - California)',
#   'member_id': 'H000213'},
#  {'member_name': 'Harper, Gregg (Republican - Mississippi)',
#   'member_id': 'H001045'},
#  {'member_name': 'Harrington, Michael J. (Democratic - Massachusetts)',
#   'member_id': 'H000230'},
#  {'member_name': 'Harris, Andy (Republican - Maryland)',
#   'member_id': 'H001052'},
#  {'member_name': 'Harris, Claude (Democratic - Alabama)',
#   'member_id': 'H000236'},
#  {'member_name': 'Harris, Herbert E., II (Democratic - Virginia)',
#   'member_id': 'H000241'},
#  {'member_name': 'Harris, Kamala D. (Democratic - California)',
#   'member_id': 'H001075'},
#  {'member_name': 'Harris, Katherine (Republican - Florida)',
#   'member_id': 'H001035'},
#  {'member_name': 'Harrison, Frank (Democratic - Pennsylvania)',
#   'member_id': 'H000269'},
#  {'member_name': 'Harsha, William H. (Republican - Ohio)',
#   'member_id': 'H000281'},
#  {'member_name': 'Harshbarger, Diana (Republican - Tennessee)',
#   'member_id': 'H001086'},
#  {'member_name': 'Hart, Gary W. (Democratic - Colorado)',
#   'member_id': 'H000287'},
#  {'member_name': 'Hart, Melissa A. (Republican - Pennsylvania)',
#   'member_id': 'H001033'},
#  {'member_name': 'Hart, Philip A. (Democratic - Michigan)',
#   'member_id': 'H000291'},
#  {'member_name': 'Hartke, Vance (Democratic - Indiana)',
#   'member_id': 'H000297'},
#  {'member_name': 'Hartnett, Thomas F. (Republican - South Carolina)',
#   'member_id': 'H000302'},
#  {'member_name': 'Hartzler, Vicky (Republican - Missouri)',
#   'member_id': 'H001053'},
#  {'member_name': 'Harvey, James (Republican - Michigan)',
#   'member_id': 'H000306'},
#  {'member_name': 'Haskell, Floyd K. (Democratic - Colorado)',
#   'member_id': 'H000317'},
#  {'member_name': 'Hassan, Margaret Wood (Democratic - New Hampshire)',
#   'member_id': 'H001076'},
#  {'member_name': 'Hastert, J. Dennis (Republican - Illinois)',
#   'member_id': 'H000323'},
#  {'member_name': 'Hastings, Alcee L. (Democratic - Florida)',
#   'member_id': 'H000324'},
#  {'member_name': 'Hastings, Doc (Republican - Washington)',
#   'member_id': 'H000329'},
#  {'member_name': 'Hastings, James F. (Republican - New York)',
#   'member_id': 'H000327'},
#  {'member_name': 'Hatch, Orrin G. (Republican - Utah)',
#   'member_id': 'H000338'},
#  {'member_name': 'Hatcher, Charles (Democratic - Georgia)',
#   'member_id': 'H000340'},
#  {'member_name': 'Hatfield, Mark O. (Republican - Oregon)',
#   'member_id': 'H000343'},
#  {'member_name': 'Hatfield, Paul (Democratic - Montana)',
#   'member_id': 'H000344'},
#  {'member_name': 'Hathaway, William D. (Democratic - Maine)',
#   'member_id': 'H000346'},
#  {'member_name': 'Hawkins, Augustus F. (Democratic - California)',
#   'member_id': 'H000367'},
#  {'member_name': 'Hawkins, Paula (Republican - Florida)',
#   'member_id': 'H000374'},
#  {'member_name': 'Hawley, Josh (Republican - Missouri)',
#   'member_id': 'H001089'},
#  {'member_name': 'Hayakawa, Samuel Ichiye (Republican - California)',
#   'member_id': 'H000384'},
#  ...]

# %%
df1 = pd.DataFrame(congress_IDs)

# %%
df1['name'] = df1.member_name.str.extract("^(.+)\s\(.*")

# %%
df1['party'] = df1.member_name.str.extract("\s\((\w+)\s-\s\w+")

# %%
df1['state'] = df1.member_name.str.extract("-\s(.+)\)")

# %%
df1.head()
# Out:
#                                    member_name member_id                name  \
# 0     Abraham, Spencer (Republican - Michigan)   A000355    Abraham, Spencer
# 1    Abdnor, James (Republican - South Dakota)   A000009       Abdnor, James
# 2      Abercrombie, Neil (Democratic - Hawaii)   A000014   Abercrombie, Neil
# 3  Abourezk, James (Democratic - South Dakota)   A000017     Abourezk, James
# 4  Abraham, Ralph Lee (Republican - Louisiana)   A000374  Abraham, Ralph Lee
#
#         party         state
# 0  Republican      Michigan
# 1  Republican  South Dakota
# 2  Democratic        Hawaii
# 3  Democratic  South Dakota
# 4  Republican     Louisiana

# %%
merged = df.merge(df1, how='left', left_on='bioguide_id', right_on='member_id')

# %%
merged.head()
# Out:
#             Date  \
# 0  4/30/20 19:47
# 1  4/30/20 19:32
# 2  4/30/20 18:41
# 3  4/30/20 18:40
# 4  4/30/20 18:20
#
#                                                                                                     Subject  \
# 0  Fincantieri Marinette Marine Wins Guided-Missile Frigate Contract, Major Win For Upper Peninsula Workers
# 1                                                         April 30: A Doctor's Note on Coronavirus in TX-26
# 2                                                                          COVID-19 Update | April 30, 2020
# 3                Congresswoman Beatty Recognizes Front Line Workers and Connects With Central Ohio Seniors
# 4                                                                NEW UPDATE: Expanded Unemployment Benefits
#
#                                                                                                                                                                                                    Message  \
# 0    \n￼\n\nFOR IMMEDIATE RELEASE:  \nApril 30, 2020\nCONTACT:\nJames Hogge 231-640-9158\n\n\nFincantieri Marinette Marine Wins Guided-Missile Frigate Contract, Major Win For Upper Peninsula Workers\...
# 1  ￼\nApril 30, 2020
#
# Dear Friends,
#
# Tonight, I will be hosting a tele-townhall about this Coronavirus Pandemic. My intention is to hear first-hand from Texas-26 and how they have been affected by th...
# 2  COVID-19 Update | April 30, 2020\nView Email in Browser \n￼ \nDear Friends,\n\nAs we come to the end of National Child Abuse Prevention Month, it is important that we remain vigilant to protect th...
# 3  ￼\n￼\n￼\n￼\n￼\n￼\n￼\n￼\nCongresswoman Beatty Recognizes Front Line Workers and Connects With Central Ohio Seniors \nU.S. Congresswoman Joyce Beatty (OH-03) and her staff recently sent cards and th...
# 4  ￼  \nDear Friend,
#
# Report after report is highlighting what families in every corner of Oregon already know firsthand: The economic impacts of the coronavirus are dire, with big implications for ...
#
#   bioguide_id                               member_name member_id  \
# 0     B001301     Bergman, Jack (Republican - Michigan)   B001301
# 1     B001248  Burgess, Michael C. (Republican - Texas)   B001248
# 2     H001072   Hill, J. French (Republican - Arkansas)   H001072
# 3     B001281         Beatty, Joyce (Democratic - Ohio)   B001281
# 4     M001176       Merkley, Jeff (Democratic - Oregon)   M001176
#
#                   name       party     state
# 0        Bergman, Jack  Republican  Michigan
# 1  Burgess, Michael C.  Republican     Texas
# 2      Hill, J. French  Republican  Arkansas
# 3        Beatty, Joyce  Democratic      Ohio
# 4        Merkley, Jeff  Democratic    Oregon

# %%
merged = merged.drop(columns=['member_name'])
