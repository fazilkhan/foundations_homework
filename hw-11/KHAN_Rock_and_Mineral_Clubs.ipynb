# %% [markdown]
# # Rock and Mineral Clubs
#
# Scrape all of the rock and mineral clubs listed at https://rocktumbler.com/blog/rock-and-mineral-clubs/ (but don't just cut and paste!)
#
# Save a CSV called `rock-clubs.csv` with the name of the club, their URL, and the city they're located in.
#
# **Bonus**: Add a column for the state. There are a few ways to do this, but knowing that `element.parent` goes 'up' one element might be helpful.
#
# * _**Hint:** The name of the club and the city are both inside of td elements, and they aren't distinguishable by class. Instead you'll just want to ask for all of the tds and then just ask for the text from the first or second one._
# * _**Hint:** If you use BeautifulSoup, you can select elements by attributes other than class or id - instead of `doc.find_all({'class': 'cat'})` you can do things like `doc.find_all({'other_attribute': 'blah'})` (sorry for the awful example)._
# * _**Hint:** If you love `pd.read_html` you might also be interested in `pd.concat` and potentially `list()`. But you'll have to clean a little more!_

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import numpy as np
import lxml
from bs4 import BeautifulSoup
import requests
import re
driver = webdriver.Chrome()
# Out:
# /Users/khanfazil/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
driver.get("https://rocktumbler.com/blog/rock-and-mineral-clubs/")

# %%
rows = driver.find_elements_by_tag_name('tr')

# %%
club_list = []
for row in rows:
    try:
        state = row.find_elements_by_tag_name('h3')[0].text.strip()
    except:
        pass
        try:
    #         print(row.find_elements_by_tag_name('h3')[0].text.strip())
            name_club = row.find_element_by_tag_name('a').text.strip()
            url = row.find_element_by_tag_name('a').get_attribute('href')
            place = row.find_elements_by_tag_name('td')[1].text.strip()
    #         print("-----")
        except:
            pass
        club = {
            'state': state,
            'name_club': name_club,
            'url': url,
            'place': place
        }
        club_list.append(club)

# %%
# Honestly, I have no idea why I had to put the first line for the state in a separate tray loop.
# But when I had all that in one single loop it just didn't work. In fact, the code for state worked but I keep 
# getting erros on the remaining variables that they were not defined. Interestingly, each time I 'print(ed)' them
# but when I tried to save them to a variable and save them to a list, the loop brooke. This is just a random
# solution found with a lot of trial and error. Also, the Selenium window closed on its own after running this loop
# but I got what I wanted so I am not complaining.

# %%
df = pd.DataFrame(club_list)
df.head(20)
# Out:
#                              state                                  name_club  \
# 0   Alabama Rock and Mineral Clubs         Alabama Mineral & Lapidary Society
# 1   Alabama Rock and Mineral Clubs                  Dothan Gem & Mineral Club
# 2   Alabama Rock and Mineral Clubs         Huntsville Gem and Mineral Society
# 3   Alabama Rock and Mineral Clubs                  Mobile Rock & Gem Society
# 4   Alabama Rock and Mineral Clubs           Montgomery Gem & Mineral Society
# 5    Alaska Rock and Mineral Clubs              Chugach Gem & Mineral Society
# 6    Alaska Rock and Mineral Clubs               Mat-Su Rock and Mineral Club
# 7   Arizona Rock and Mineral Clubs          Apache Junction Rock and Gem Club
# 8   Arizona Rock and Mineral Clubs                Black Canyon City Rock Club
# 9   Arizona Rock and Mineral Clubs         Daisy Mountain Rock & Mineral Club
# 10  Arizona Rock and Mineral Clubs          Gila County Gem & Mineral Society
# 11  Arizona Rock and Mineral Clubs              Huachuca Mineral and Gem Club
# 12  Arizona Rock and Mineral Clubs          Lake Havasu Gem & Mineral Society
# 13  Arizona Rock and Mineral Clubs           Mineralogical Society of Arizona
# 14  Arizona Rock and Mineral Clubs                  Mingus Gem & Mineral Club
# 15  Arizona Rock and Mineral Clubs                   Mohave County Gemstoners
# 16  Arizona Rock and Mineral Clubs                   Old Pueblo Lapidary Club
# 17  Arizona Rock and Mineral Clubs              Pinal Gem and Mineral Society
# 18  Arizona Rock and Mineral Clubs                Prescott Gem & Mineral Club
# 19  Arizona Rock and Mineral Clubs  Quartzsite Roadrunners Gem & Mineral Club
#
#                                                   url              place
# 0                        http://www.lapidaryclub.com/         Birmingham
# 1                 http://www.wiregrassrockhounds.com/             Dothan
# 2                           http://huntsvillegms.org/         Huntsville
# 3                    http://www.mobilerockandgem.com/             Mobile
# 4     http://montgomerygemandmineralsociety.com/mgms/         Montgomery
# 5         http://www.chugachgemandmineralsociety.com/          Anchorage
# 6                           http://matsurockclub.com/             Palmer
# 7                          http://www.ajrockclub.com/    Apache Junction
# 8                  http://www.bccrockclub.mysite.com/  Black Canyon City
# 9                               http://www.dmrmc.com/             Anthem
# 10                                http://gilagem.org/              Miami
# 11         http://www.huachucamineralandgemclub.info/       Sierra Vista
# 12                      http://www.lakehavasugms.org/   Lake Havasu City
# 13                              http://www.msaaz.org/         Scottsdale
# 14                         http://www.mingusclub.org/         Cottonwood
# 15                         http://www.gemstoners.org/            Kingman
# 16                       http://www.lapidaryclub.org/             Tucson
# 17  https://www.pinalgeologymuseum.org/index.php/p...           Coolidge
# 18                 http://www.prescottgemmineral.org/    Prescott Valley
# 19                              http://www.qrgmc.org/         Quartzsite

# %%
df.to_csv("rock-clubs.csv", index=False)
