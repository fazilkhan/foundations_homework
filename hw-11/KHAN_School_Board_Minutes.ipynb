# %% [markdown]
# # School Board Minutes
#
# Scrape all of the school board minutes from http://www.mineral.k12.nv.us/pages/School_Board_Minutes
#
# Save a CSV called `minutes.csv` with the date and the URL to the file. The date should be formatted as YYYY-MM-DD.
#
# **Bonus:** Download the PDF files
#
# **Bonus 2:** Use [PDF OCR X](https://solutions.weblite.ca/pdfocrx/index.php) on one of the PDF files and see if it can be converted into text successfully.
#
# * **Hint:** If you're just looking for links, there are a lot of other links on that page! Can you look at the link to know whether it links or minutes or not? You'll want to use an "if" statement.
# * **Hint:** You could also filter out bad links later on using pandas instead of when scraping
# * **Hint:** If you get a weird error that you can't really figure out, you can always tell Python to just ignore it using `try` and `except`, like below. Python will try to do the stuff inside of 'try', but if it hits an error it will skip right out.
# * **Hint:** Remember the codes at http://strftime.org
# * **Hint:** If you have a date that you've parsed, you can use `.dt.strftime` to turn it into a specially-formatted string. You use the same codes (like %B etc) that you use for converting strings into dates.
#
# ```python
# try:
#   blah blah your code
#   your code
#   your code
# except:
#   pass
# ```
#
# * **Hint:** You can use `.apply` to download each pdf, or you can use one of a thousand other ways. It'd be good `.apply` practice though!

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import numpy as np
import lxml
from bs4 import BeautifulSoup
import requests
import re
driver = webdriver.Chrome()

# %%
driver.get("http://www.mineral.k12.nv.us/pages/School_Board_Minutes")

# %%
elements = driver.find_elements_by_tag_name('a')

# %%
school_min = []
for element in elements[17:74]:
    date = element.text.strip()
    min_url = element.get_attribute('href')
    minutes = {
        'date': date,
        'min_url': min_url
    }
    school_min.append(minutes)
school_min
# Out:
# [{'date': 'September 1, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/9.1.20_minutes.pdf'},
#  {'date': 'August 11, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/8.11.20_minutes.pdf'},
#  {'date': 'July 28, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/7.28.20_minutes.pdf'},
#  {'date': 'July 14, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/7.14.20_minutes.pdf'},
#  {'date': 'June 16, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.16.20_minutes.pdf'},
#  {'date': 'May 20, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/5.20.20_minutes.pdf'},
#  {'date': 'April 7, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/4.7.20_minutes.pdf'},
#  {'date': 'March 12, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/3.12.20_minutes.pdf'},
#  {'date': 'March 5, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/3.5.20_minutes.pdf'},
#  {'date': 'February 21, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/2.21.20_minutes.pdf'},
#  {'date': 'February 4, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/2-4-20_minutes.pdf'},
#  {'date': 'January 21, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/1.21.20.pdf'},
#  {'date': 'January 7, 2020',
#   'min_url': 'http://www.mineral.k12.nv.us/files/1.7.20_pdf.pdf'},
#  {'date': 'December 16, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/12.16.19_minutes.pdf'},
#  {'date': 'December 3, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/12.3.19_minutes.pdf'},
#  {'date': 'November 19, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/11.19.19_minutes.pdf'},
#  {'date': 'November 5, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/11.5.19_minutes.pdf'},
#  {'date': 'October 15, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/10.15.19_minutes.pdf'},
#  {'date': 'September 17, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/9.17.19_minutes.pdf'},
#  {'date': 'September 3, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/9.3.19_minutes.pdf'},
#  {'date': 'August 20, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/doc04504220191028190253.pdf'},
#  {'date': 'August 10, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/8.10.19_minutes.pdf'},
#  {'date': 'August 6, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/8.6.19_minutes.pdf'},
#  {'date': 'July 16, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/7.16.19_minutes.pdf'},
#  {'date': 'June 18, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.18.19_minutes.pdf'},
#  {'date': 'June 4, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.4.19_minutes.pdf'},
#  {'date': 'May 28, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/5.28.19_minutes.pdf'},
#  {'date': 'May 7, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/5.7.19_minutes.pdf'},
#  {'date': 'April 23, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/4.23.19_minutes.pdf'},
#  {'date': 'April 8, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/4.8.19_minutes.pdf'},
#  {'date': 'March 19, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/3.5.19_minutes.pdf'},
#  {'date': 'March 5, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/3.5.19.pdf'},
#  {'date': 'February 26, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/2.26.19_minutes.pdf'},
#  {'date': 'February 5, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/2.5.19_minutes.pdf'},
#  {'date': 'January 22, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/January_22_minutes.pdf'},
#  {'date': 'January 8, 2019',
#   'min_url': 'http://www.mineral.k12.nv.us/files/January_8_minutes.pdf'},
#  {'date': 'December 20, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/12.20.18_minutes.pdf'},
#  {'date': 'December 4, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/12.4.18_minutes.pdf'},
#  {'date': 'November 20, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/11.20.18.pdf'},
#  {'date': 'September 25, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/9.25.18_minutes.pdf'},
#  {'date': 'September 13, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/9.13.18_minutes.pdf'},
#  {'date': 'September 4, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/9.4.18.pdf'},
#  {'date': 'August 21, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/8.21.18_minutes.pdf'},
#  {'date': 'August 7, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/8.7.18_minutes.pdf'},
#  {'date': 'July 24, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/7.24.18_minutes.pdf'},
#  {'date': 'July 10, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/7.10.18_minutes.pdf'},
#  {'date': 'June 28, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.28.18.pdf'},
#  {'date': 'June 22, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.22.18_minutes.pdf'},
#  {'date': 'June 21, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.21.18.pdf'},
#  {'date': 'June 19, 2108',
#   'min_url': 'http://www.mineral.k12.nv.us/files/6.19.18_minutes.pdf'},
#  {'date': 'May 29, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/5.29.18_minutes.pdf'},
#  {'date': 'April 17, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/4.17.18.pdf'},
#  {'date': 'April 2, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/april_2,_2018_minutes.pdf'},
#  {'date': 'March 8, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/3.8.18.pdf'},
#  {'date': 'March 6, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/march_6,_2018_minutes.pdf'},
#  {'date': 'February 20, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/feb_20,_2108_minutes.pdf'},
#  {'date': 'February 6, 2018',
#   'min_url': 'http://www.mineral.k12.nv.us/files/2.6.18_minutes.pdf'}]

# %%
df = pd.DataFrame(school_min)
df.head()
# Out:
#                 date                                            min_url
# 0  September 1, 2020  http://www.mineral.k12.nv.us/files/9.1.20_minu...
# 1    August 11, 2020  http://www.mineral.k12.nv.us/files/8.11.20_min...
# 2      July 28, 2020  http://www.mineral.k12.nv.us/files/7.28.20_min...
# 3      July 14, 2020  http://www.mineral.k12.nv.us/files/7.14.20_min...
# 4      June 16, 2020  http://www.mineral.k12.nv.us/files/6.16.20_min...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.tail()
# Out:
#          date                                            min_url
# 52 2018-04-02  http://www.mineral.k12.nv.us/files/april_2,_20...
# 53 2018-03-08      http://www.mineral.k12.nv.us/files/3.8.18.pdf
# 54 2018-03-06  http://www.mineral.k12.nv.us/files/march_6,_20...
# 55 2018-02-20  http://www.mineral.k12.nv.us/files/feb_20,_210...
# 56 2018-02-06  http://www.mineral.k12.nv.us/files/2.6.18_minu...

# %%
import urllib.request

# %%
for row in df.iterrows():
    response = urllib.request.urlopen(row[1]['min_url'])
#     print(row)
    file = open(f"/Users/khanfazil/Documents/python_soma/homework/11-homework/school_min_pdfs/{row[1]['date']}.pdf", 'wb')
    file.write(response.read())
    file.close()

# %%
# Sorry for using a for loop with a dataframe, still don't understand how apply works. Please don't cut my fingers.
